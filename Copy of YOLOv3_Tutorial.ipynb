# %% [markdown]
# # Building a YOLOv3 Object Detector with Darknet in the Cloud! (GPU ENABLED)
# This tutorial will help you build YOLOv3 easily in the cloud with GPU enabled so that you can run real-time object detections as well as train your very own custom object detector!

# %% [markdown]
# # Step 1: Enabling GPU within your notebook
# You need to enable GPU acceleration within your Colab notebook so that your YOLOv3 system will be able to process detections over 100 faster than CPU.
#
# ### Steps:
#
# ### i) Click **Edit** at top left of your notebook
# ![image.png](data:image/png;base64,...)
# ### ii) Click **Notebook Settings** within dropdown
# ![image.png](data:image/png;base64,...)
# ### iii) Under 'Hardware Accelerator' select **GPU** and then hit **Save**
# ![image.png](data:image/png;base64,...)
#
# Your notebook should now have GPU enabled!

# %% [markdown]
# # Step 2: Cloning and Building Darknet
# The following cells will clone darknet from AlexeyAB's famous repository, adjust the Makefile to enable OPENCV and GPU for darknet and then build darknet.
#
# Do not worry about any warnings when you run the '!make' cell!

# %%
# clone darknet repo
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15833, done.
# remote: Total 15833 (delta 0), reused 0 (delta 0), pack-reused 15833
# Receiving objects: 100% (15833/15833), 14.39 MiB | 14.09 MiB/s, done.
# Resolving deltas: 100% (10666/10666), done.

# %%
# change makefile to have GPU and OPENCV enabled
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
#!sed -i 's/GPU=0/GPU=1/' Makefile
#!sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# Out:
# /content/darknet

# %%
# verify CUDA
# !/usr/local/cuda/bin/nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Tue_Aug_15_22:02:13_PDT_2023
# Cuda compilation tools, release 12.2, V12.2.140
# Build cuda_12.2.r12.2/compiler.33191640_0

# %%
# make darknet (build)
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# mkdir -p results
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:945:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#   945 |                 float rgb[3];
#       |                       ^~~
# ./src/image_opencv.cpp: In function ‘void cv_draw_object(image, float*, int, int, int*, float*, int*, int, char**)’:
# ./src/image_opencv.cpp:1443:14: warning: unused variable ‘buff’ [-Wunused-variable]
#  1443 |         char buff[100];
#       |              ^~~~
# ./src/image_opencv.cpp:1419:9: warning: unused variable ‘it_tb_res’ [-Wunused-variable]
#  1419 |     int it_tb_res = cv::createTrackbar(it_trackbar_name, window_name, &it_trackbar_value, 1000);
#       |         ^~~~~~~~~
# ./src/image_opencv.cpp:1423:9: warning: unused variable ‘lr_tb_res’ [-Wunused-variable]
#  1423 |     int lr_tb_res = cv::createTrackbar(lr_trackbar_name, window_name, &lr_trackbar_value, 20);
#       |         ^~~~~~~~~
# ./src/image_opencv.cpp:1427:9: warning: unused variable ‘cl_tb_res’ [-Wunused-variable]
#  1427 |     int cl_tb_res = cv::createTrackbar(cl_trackbar_name, window_name, &cl_trackbar_value, classes-1);
#       |         ^~~~~~~~~
# ./src/image_opencv.cpp:1430:9: warning: unused variable ‘bo_tb_res’ [-Wunused-variable]
#  1430 |     int bo_tb_res = cv::createTrackbar(bo_trackbar_name, window_name, boxonly, 1);
#       |         ^~~~~~~~~
# ./src/image_opencv.cpp: At global scope:
# ./src/image_opencv.cpp:449:14: warning: ‘float get_pixel(image, int, int, int)’ defined but not used [-Wunused-function]
#   449 | static float get_pixel(image m, int x, int y, int c)
#       |              ^~~~~~~~~
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/http_stream.cpp -o obj/http_stream.o
# ./src/http_stream.cpp: In member function ‘bool JSON_sender::write(const char*)’:
# ./src/http_stream.cpp:253:21: warning: unused variable ‘n’ [-Wunused-variable]
#   253 |                 int n = _write(client, outputbuf, outlen);
#       |                     ^
# ./src/http_stream.cpp: In function ‘void set_track_id(detection*, int, float, float, float, int, int, int)’:
# ./src/http_stream.cpp:866:27: warning: comparison of integer expressions of different signedness: ‘int’ and ‘std::vector<detection_t>::size_type’ {aka ‘long unsigned int’} [-Wsign-compare]
#   866 |         for (int i = 0; i < v.size(); ++i) {
#       |                         ~~^~~~~~~~~~
# ./src/http_stream.cpp:874:33: warning: comparison of integer expressions of different signedness: ‘int’ and ‘std::vector<detection_t>::size_type’ {aka ‘long unsigned int’} [-Wsign-compare]
#   874 |     for (int old_id = 0; old_id < old_dets.size(); ++old_id) {
#       |                          ~~~~~~~^~~~~~~~~~~~~~~~~
# ./src/http_stream.cpp:893:31: warning: comparison of integer expressions of different signedness: ‘int’ and ‘std::vector<detection_t>::size_type’ {aka ‘long unsigned int’} [-Wsign-compare]
#   893 |     for (int index = 0; index < new_dets_num*old_dets.size(); ++index) {
#       |                         ~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ./src/http_stream.cpp:929:28: warning: comparison of integer expressions of different signedness: ‘std::deque<std::vector<detection_t> >::size_type’ {aka ‘long unsigned int’} and ‘int’ [-Wsign-compare]
#   929 |     if (old_dets_dq.size() > deque_size) old_dets_dq.pop_front();
#       |         ~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/gemm.c -o obj/gemm.o
# ./src/gemm.c: In function ‘convolution_2d’:
# ./src/gemm.c:2042:15: warning: unused variable ‘out_w’ [-Wunused-variable]
#  2042 |     const int out_w = (w + 2 * pad - ksize) / stride + 1;    // output_width=input_width for stride=1 and pad=1
#       |               ^~~~~
# ./src/gemm.c:2041:15: warning: unused variable ‘out_h’ [-Wunused-variable]
#  2041 |     const int out_h = (h + 2 * pad - ksize) / stride + 1;    // output_height=input_height for stride=1 and pad=1
#       |               ^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/utils.c -o obj/utils.o
# ./src/utils.c: In function ‘custom_hash’:
# ./src/utils.c:1093:12: warning: suggest parentheses around assignment used as truth value [-Wparentheses]
#  1093 |     while (c = *str++)
#       |            ^
# In file included from /usr/include/string.h:535,
#                  from include/darknet.h:14,
#                  from ./src/utils.h:3,
#                  from ./src/utils.c:4:
# In function ‘strncpy’,
#     inlined from ‘copy_string’ at ./src/utils.c:563:5:
# /usr/include/x86_64-linux-gnu/bits/string_fortified.h:95:10: warning: ‘__builtin_strncpy’ specified bound depends on the length of the source argument [-Wstringop-truncation]
#    95 |   return __builtin___strncpy_chk (__dest, __src, __len,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    96 |                                   __glibc_objsize (__dest));
#       |                                   ~~~~~~~~~~~~~~~~~~~~~~~~~
# ./src/utils.c: In function ‘copy_string’:
# ./src/utils.c:563:22: note: length computed here
#   563 |     strncpy(copy, s, strlen(s)+1);
#       |                      ^~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/dark_cuda.c -o obj/dark_cuda.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/convolutional_layer.c -o obj/convolutional_layer.o
# ./src/convolutional_layer.c: In function ‘resize_convolutional_layer’:
# ./src/convolutional_layer.c:891:9: warning: unused variable ‘old_h’ [-Wunused-variable]
#   891 |     int old_h = l->h;
#       |         ^~~~~
# ./src/convolutional_layer.c:890:9: warning: unused variable ‘old_w’ [-Wunused-variable]
#   890 |     int old_w = l->w;
#       |         ^~~~~
# ./src/convolutional_layer.c: In function ‘forward_convolutional_layer’:
# ./src/convolutional_layer.c:1335:32: warning: unused variable ‘t_intput_size’ [-Wunused-variable]
#  1335 |                         size_t t_intput_size = binary_transpose_align_input(k, n, state.workspace, &l.t_bit_input, ldb_align, l.bit_align);
#       |                                ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/list.c -o obj/list.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/image.c -o obj/image.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/activations.c -o obj/activations.o
# ./src/activations.c: In function ‘activate’:
# ./src/activations.c:79:5: warning: enumeration value ‘RELU6’ not handled in switch [-Wswitch]
#    79 |     switch(a){
#       |     ^~~~~~
# ./src/activations.c:79:5: warning: enumeration value ‘SWISH’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘MISH’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘HARD_MISH’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘NORM_CHAN’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘NORM_CHAN_SOFTMAX’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘NORM_CHAN_SOFTMAX_MAXVAL’ not handled in switch [-Wswitch]
# ./src/activations.c: In function ‘gradient’:
# ./src/activations.c:310:5: warning: enumeration value ‘SWISH’ not handled in switch [-Wswitch]
#   310 |     switch(a){
#       |     ^~~~~~
# ./src/activations.c:310:5: warning: enumeration value ‘MISH’ not handled in switch [-Wswitch]
# ./src/activations.c:310:5: warning: enumeration value ‘HARD_MISH’ not handled in switch [-Wswitch]
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/im2col.c -o obj/im2col.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/col2im.c -o obj/col2im.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/blas.c -o obj/blas.o
# ./src/blas.c: In function ‘backward_shortcut_multilayer_cpu’:
# ./src/blas.c:207:21: warning: unused variable ‘out_index’ [-Wunused-variable]
#   207 |                 int out_index = id;
#       |                     ^~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/crop_layer.c -o obj/crop_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/dropout_layer.c -o obj/dropout_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/maxpool_layer.c -o obj/maxpool_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/softmax_layer.c -o obj/softmax_layer.o
# ./src/softmax_layer.c: In function ‘forward_contrastive_layer’:
# ./src/softmax_layer.c:242:27: warning: variable ‘max_truth’ set but not used [-Wunused-but-set-variable]
#   242 |                     float max_truth = 0;
#       |                           ^~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/data.c -o obj/data.o
# ./src/data.c: In function ‘load_data_detection’:
# ./src/data.c:1289:24: warning: unused variable ‘x’ [-Wunused-variable]
#  1289 |                 int k, x, y;
#       |                        ^
# ./src/data.c:1076:43: warning: variable ‘r_scale’ set but not used [-Wunused-but-set-variable]
#  1076 |     float r1 = 0, r2 = 0, r3 = 0, r4 = 0, r_scale = 0;
#       |                                           ^~~~~~~
# ./src/data.c: In function ‘fill_truth_detection’:
# ./src/data.c:431:33: warning: ‘%s’ directive writing up to 4095 bytes into a region of size 251 [-Wformat-overflow=]
#   431 |             sprintf(buff, "echo %s \"Wrong annotation: w = %f\" >> bad_label.list", labelpath, w);
#       |                                 ^~                                                  ~~~~~~~~~
# ./src/data.c:431:27: note: assuming directive output of 8 bytes
#   431 |             sprintf(buff, "echo %s \"Wrong annotation: w = %f\" >> bad_label.list", labelpath, w);
#       |                           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# In file included from /usr/include/stdio.h:894,
#                  from include/darknet.h:13,
#                  from ./src/data.h:5,
#                  from ./src/data.c:1:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:38:10: note: ‘__builtin___sprintf_chk’ output between 52 and 4461 bytes into a destination of size 256
#    38 |   return __builtin___sprintf_chk (__s, __USE_FORTIFY_LEVEL - 1,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    39 |                                   __glibc_objsize (__s), __fmt,
#       |                                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    40 |                                   __va_arg_pack ());
#       |                                   ~~~~~~~~~~~~~~~~~
# ./src/data.c:437:33: warning: ‘%s’ directive writing up to 4095 bytes into a region of size 251 [-Wformat-overflow=]
#   437 |             sprintf(buff, "echo %s \"Wrong annotation: h = %f\" >> bad_label.list", labelpath, h);
#       |                                 ^~                                                  ~~~~~~~~~
# ./src/data.c:437:27: note: assuming directive output of 8 bytes
#   437 |             sprintf(buff, "echo %s \"Wrong annotation: h = %f\" >> bad_label.list", labelpath, h);
#       |                           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# In file included from /usr/include/stdio.h:894,
#                  from include/darknet.h:13,
#                  from ./src/data.h:5,
#                  from ./src/data.c:1:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:38:10: note: ‘__builtin___sprintf_chk’ output between 52 and 4461 bytes into a destination of size 256
#    38 |   return __builtin___sprintf_chk (__s, __USE_FORTIFY_LEVEL - 1,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    39 |                                   __glibc_objsize (__s), __fmt,
#       |                                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    40 |                                   __va_arg_pack ());
#       |                                   ~~~~~~~~~~~~~~~~~
# ./src/data.c:424:33: warning: ‘%s’ directive writing up to 4095 bytes into a region of size 251 [-Wformat-overflow=]
#   424 |             sprintf(buff, "echo %s \"Wrong annotation: x = %f, y = %f\" >> bad_label.list", labelpath, x, y);
#       |                                 ^~                                                          ~~~~~~~~~
# ./src/data.c:424:27: note: assuming directive output of 8 bytes
#   424 |             sprintf(buff, "echo %s \"Wrong annotation: x = %f, y = %f\" >> bad_label.list", labelpath, x, y);
#       |                           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ./src/data.c:424:27: note: assuming directive output of 8 bytes
# In file included from /usr/include/stdio.h:894,
#                  from include/darknet.h:13,
#                  from ./src/data.h:5,
#                  from ./src/data.c:1:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:38:10: note: ‘__builtin___sprintf_chk’ output between 61 and 4784 bytes into a destination of size 256
#    38 |   return __builtin___sprintf_chk (__s, __USE_FORTIFY_LEVEL - 1,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    39 |                                   __glibc_objsize (__s), __fmt,
#       |                                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    40 |                                   __va_arg_pack ());
#       |                                   ~~~~~~~~~~~~~~~~~
# ./src/data.c:417:33: warning: ‘%s’ directive writing up to 4095 bytes into a region of size 251 [-Wformat-overflow=]
#   417 |             sprintf(buff, "echo %s \"Wrong annotation: x = 0 or y = 0\" >> bad_label.list", labelpath);
#       |                                 ^~                                                          ~~~~~~~~~
# In file included from /usr/include/stdio.h:894,
#                  from include/darknet.h:13,
#                  from ./src/data.h:5,
#                  from ./src/data.c:1:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:38:10: note: ‘__builtin___sprintf_chk’ output between 59 and 4154 bytes into a destination of size 256
#    38 |   return __builtin___sprintf_chk (__s, __USE_FORTIFY_LEVEL - 1,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    39 |                                   __glibc_objsize (__s), __fmt,
#       |                                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    40 |                                   __va_arg_pack ());
#       |                                   ~~~~~~~~~~~~~~~~~
# ./src/data.c:404:33: warning: ‘%s’ directive writing up to 4095 bytes into a region of size 251 [-Wformat-overflow=]
#   404 |             sprintf(buff, "echo %s \"Wrong annotation: class_id = %d. But class_id should be [from 0 to %d]\" >> bad_label.list", labelpath, id, (classes-1));
#       |                                 ^~                                                                                                ~~~~~~~~~
# In file included from /usr/include/stdio.h:894,
#                  from include/darknet.h:13,
#                  from ./src/data.h:5,
#                  from ./src/data.c:1:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:38:10: note: ‘__builtin___sprintf_chk’ output between 95 and 4210 bytes into a destination of size 256
#    38 |   return __builtin___sprintf_chk (__s, __USE_FORTIFY_LEVEL - 1,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    39 |                                   __glibc_objsize (__s), __fmt,
#       |                                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    40 |                                   __va_arg_pack ());
#       |                                   ~~~~~~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/matrix.c -o obj/matrix.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/network.c -o obj/network.o
# ./src/network.c: In function ‘train_network_waitkey’:
# ./src/network.c:435:13: warning: unused variable ‘ema_period’ [-Wunused-variable]
#   435 |         int ema_period = (net.max_batches - ema_start_point - 1000) * (1.0 - net.ema_alpha);
#       |             ^~~~~~~~~~
# At top level:
# ./src/network.c:1284:14: warning: ‘relu’ defined but not used [-Wunused-function]
#  1284 | static float relu(float src) {
#       |              ^~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/connected_layer.c -o obj/connected_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/cost_layer.c -o obj/cost_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/parser.c -o obj/parser.o
# ./src/parser.c: In function ‘save_implicit_weights’:
# ./src/parser.c:1893:9: warning: unused variable ‘i’ [-Wunused-variable]
#  1893 |     int i;
#       |         ^
# ./src/parser.c: In function ‘get_classes_multipliers’:
# ./src/parser.c:435:40: warning: argument 1 range [18446744071562067968, 18446744073709551615] exceeds maximum object size 9223372036854775807 [-Walloc-size-larger-than=]
#   435 |         classes_multipliers = (float *)calloc(classes_counters, sizeof(float));
#       |                                        ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# In file included from ./src/parser.c:3:
# /usr/include/stdlib.h:543:14: note: in a call to allocation function ‘calloc’ declared here
#   543 | extern void *calloc (size_t __nmemb, size_t __size)
#       |              ^~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/option_list.c -o obj/option_list.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/darknet.c -o obj/darknet.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/detection_layer.c -o obj/detection_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/captcha.c -o obj/captcha.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/route_layer.c -o obj/route_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/writing.c -o obj/writing.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/box.c -o obj/box.o
# ./src/box.c: In function ‘box_iou_kind’:
# ./src/box.c:154:5: warning: enumeration value ‘MSE’ not handled in switch [-Wswitch]
#   154 |     switch(iou_kind) {
#       |     ^~~~~~
# ./src/box.c: In function ‘diounms_sort’:
# ./src/box.c:898:27: warning: unused variable ‘beta_prob’ [-Wunused-variable]
#   898 |                     float beta_prob = pow(dets[j].prob[k], 2) / sum_prob;
#       |                           ^~~~~~~~~
# ./src/box.c:897:27: warning: unused variable ‘alpha_prob’ [-Wunused-variable]
#   897 |                     float alpha_prob = pow(dets[i].prob[k], 2) / sum_prob;
#       |                           ^~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/nightmare.c -o obj/nightmare.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/normalization_layer.c -o obj/normalization_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/avgpool_layer.c -o obj/avgpool_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/coco.c -o obj/coco.o
# ./src/coco.c: In function ‘validate_coco_recall’:
# ./src/coco.c:248:11: warning: unused variable ‘base’ [-Wunused-variable]
#   248 |     char *base = "results/comp4_det_test_";
#       |           ^~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/dice.c -o obj/dice.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/yolo.c -o obj/yolo.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/detector.c -o obj/detector.o
# ./src/detector.c: In function ‘eliminate_bdd’:
# ./src/detector.c:585:21: warning: statement with no effect [-Wunused-value]
#   585 |                     for (k; buf[k + n] != '\0'; k++)
#       |                     ^~~
# ./src/detector.c: In function ‘validate_detector’:
# ./src/detector.c:706:13: warning: unused variable ‘mkd2’ [-Wunused-variable]
#   706 |         int mkd2 = make_directory(buff2, 0777);
#       |             ^~~~
# ./src/detector.c:704:13: warning: unused variable ‘mkd’ [-Wunused-variable]
#   704 |         int mkd = make_directory(buff, 0777);
#       |             ^~~
# ./src/detector.c: In function ‘validate_detector_map’:
# ./src/detector.c:1323:24: warning: variable ‘cur_prob’ set but not used [-Wunused-but-set-variable]
#  1323 |                 double cur_prob = 0;
#       |                        ^~~~~~~~
# ./src/detector.c:1344:15: warning: unused variable ‘class_recall’ [-Wunused-variable]
#  1344 |         float class_recall = (float)tp_for_thresh_per_class[i] / ((float)tp_for_thresh_per_class[i] + (float)(truth_classes_count[i] - tp_for_thresh_per_class[i]));
#       |               ^~~~~~~~~~~~
# ./src/detector.c:1343:15: warning: unused variable ‘class_precision’ [-Wunused-variable]
#  1343 |         float class_precision = (float)tp_for_thresh_per_class[i] / ((float)tp_for_thresh_per_class[i] + (float)fp_for_thresh_per_class[i]);
#       |               ^~~~~~~~~~~~~~~
# At top level:
# ./src/detector.c:458:12: warning: ‘get_coco_image_id’ defined but not used [-Wunused-function]
#   458 | static int get_coco_image_id(char *filename)
#       |            ^~~~~~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/layer.c -o obj/layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/compare.c -o obj/compare.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/classifier.c -o obj/classifier.o
# ./src/classifier.c: In function ‘train_classifier’:
# ./src/classifier.c:146:9: warning: unused variable ‘count’ [-Wunused-variable]
#   146 |     int count = 0;
#       |         ^~~~~
# ./src/classifier.c: In function ‘predict_classifier’:
# ./src/classifier.c:855:13: warning: unused variable ‘time’ [-Wunused-variable]
#   855 |     clock_t time;
#       |             ^~~~
# ./src/classifier.c: In function ‘demo_classifier’:
# ./src/classifier.c:1283:49: warning: unused variable ‘tval_result’ [-Wunused-variable]
#  1283 |         struct timeval tval_before, tval_after, tval_result;
#       |                                                 ^~~~~~~~~~~
# ./src/classifier.c:1283:37: warning: unused variable ‘tval_after’ [-Wunused-variable]
#  1283 |         struct timeval tval_before, tval_after, tval_result;
#       |                                     ^~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/local_layer.c -o obj/local_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/swag.c -o obj/swag.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/shortcut_layer.c -o obj/shortcut_layer.o
# ./src/shortcut_layer.c: In function ‘make_shortcut_layer’:
# ./src/shortcut_layer.c:55:15: warning: unused variable ‘scale’ [-Wunused-variable]
#    55 |         float scale = sqrt(2. / l.nweights);
#       |               ^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/representation_layer.c -o obj/representation_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/activation_layer.c -o obj/activation_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/rnn_layer.c -o obj/rnn_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/gru_layer.c -o obj/gru_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/rnn.c -o obj/rnn.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/rnn_vid.c -o obj/rnn_vid.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/crnn_layer.c -o obj/crnn_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/demo.c -o obj/demo.o
# ./src/demo.c: In function ‘detect_in_thread’:
# ./src/demo.c:100:15: warning: unused variable ‘l’ [-Wunused-variable]
#   100 |         layer l = net.layers[net.n - 1];
#       |               ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/tag.c -o obj/tag.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/cifar.c -o obj/cifar.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/go.c -o obj/go.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/batchnorm_layer.c -o obj/batchnorm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/art.c -o obj/art.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/region_layer.c -o obj/region_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/reorg_layer.c -o obj/reorg_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/reorg_old_layer.c -o obj/reorg_old_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/super.c -o obj/super.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/voxel.c -o obj/voxel.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/tree.c -o obj/tree.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/yolo_layer.c -o obj/yolo_layer.o
# ./src/yolo_layer.c: In function ‘process_batch’:
# ./src/yolo_layer.c:424:25: warning: variable ‘best_match_t’ set but not used [-Wunused-but-set-variable]
#   424 |                     int best_match_t = 0;
#       |                         ^~~~~~~~~~~~
# ./src/yolo_layer.c: In function ‘forward_yolo_layer’:
# ./src/yolo_layer.c:704:11: warning: unused variable ‘avg_anyobj’ [-Wunused-variable]
#   704 |     float avg_anyobj = 0;
#       |           ^~~~~~~~~~
# ./src/yolo_layer.c:703:11: warning: unused variable ‘avg_obj’ [-Wunused-variable]
#   703 |     float avg_obj = 0;
#       |           ^~~~~~~
# ./src/yolo_layer.c:702:11: warning: unused variable ‘avg_cat’ [-Wunused-variable]
#   702 |     float avg_cat = 0;
#       |           ^~~~~~~
# ./src/yolo_layer.c:701:11: warning: unused variable ‘recall75’ [-Wunused-variable]
#   701 |     float recall75 = 0;
#       |           ^~~~~~~~
# ./src/yolo_layer.c:700:11: warning: unused variable ‘recall’ [-Wunused-variable]
#   700 |     float recall = 0;
#       |           ^~~~~~
# ./src/yolo_layer.c:699:11: warning: unused variable ‘tot_ciou_loss’ [-Wunused-variable]
#   699 |     float tot_ciou_loss = 0;
#       |           ^~~~~~~~~~~~~
# ./src/yolo_layer.c:698:11: warning: unused variable ‘tot_diou_loss’ [-Wunused-variable]
#   698 |     float tot_diou_loss = 0;
#       |           ^~~~~~~~~~~~~
# ./src/yolo_layer.c:695:11: warning: unused variable ‘tot_ciou’ [-Wunused-variable]
#   695 |     float tot_ciou = 0;
#       |           ^~~~~~~~
# ./src/yolo_layer.c:694:11: warning: unused variable ‘tot_diou’ [-Wunused-variable]
#   694 |     float tot_diou = 0;
#       |           ^~~~~~~~
# ./src/yolo_layer.c:693:11: warning: unused variable ‘tot_giou’ [-Wunused-variable]
#   693 |     float tot_giou = 0;
#       |           ^~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/gaussian_yolo_layer.c -o obj/gaussian_yolo_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/upsample_layer.c -o obj/upsample_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/lstm_layer.c -o obj/lstm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/conv_lstm_layer.c -o obj/conv_lstm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/scale_channels_layer.c -o obj/scale_channels_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -c ./src/sam_layer.c -o obj/sam_layer.o
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV obj/image_opencv.o obj/http_stream.o obj/gemm.o obj/utils.o obj/dark_cuda.o obj/convolutional_layer.o obj/list.o obj/image.o obj/activations.o obj/im2col.o obj/col2im.o obj/blas.o obj/crop_layer.o obj/dropout_layer.o obj/maxpool_layer.o obj/softmax_layer.o obj/data.o obj/matrix.o obj/network.o obj/connected_layer.o obj/cost_layer.o obj/parser.o obj/option_list.o obj/darknet.o obj/detection_layer.o obj/captcha.o obj/route_layer.o obj/writing.o obj/box.o obj/nightmare.o obj/normalization_layer.o obj/avgpool_layer.o obj/coco.o obj/dice.o obj/yolo.o obj/detector.o obj/layer.o obj/compare.o obj/classifier.o obj/local_layer.o obj/swag.o obj/shortcut_layer.o obj/representation_layer.o obj/activation_layer.o obj/rnn_layer.o obj/gru_layer.o obj/rnn.o obj/rnn_vid.o obj/crnn_layer.o obj/demo.o obj/tag.o obj/cifar.o obj/go.o obj/batchnorm_layer.o obj/art.o obj/region_layer.o obj/reorg_layer.o obj/reorg_old_layer.o obj/super.o obj/voxel.o obj/tree.o obj/yolo_layer.o obj/gaussian_yolo_layer.o obj/upsample_layer.o obj/lstm_layer.o obj/conv_lstm_layer.o obj/scale_channels_layer.o obj/sam_layer.o -o darknet -lm -pthread `pkg-config --libs opencv4 2> /dev/null || pkg-config --libs opencv`

# %% [markdown]
# # Step 3: Download pretrained YOLOv3 weights
# YOLOv3 has been trained already on the coco dataset which has 80 classes that it can predict. We will grab these pretrained weights so that we can run YOLOv3 on these pretrained classes and get detections.

# %%
# get yolov3 pretrained coco dataset weights
# !wget https://pjreddie.com/media/files/yolov3.weights
# Out:
# --2024-03-18 07:50:30--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 162.0.215.52
# Connecting to pjreddie.com (pjreddie.com)|162.0.215.52|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  9.40MB/s    in 36s
#
# 2024-03-18 07:53:38 (6.65 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %%
# define helper functions
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()

# use this to upload files
def upload():
  from google.colab import files
  uploaded = files.upload()
  for name, data in uploaded.items():
    with open(name, 'wb') as f:
      f.write(data)
      print ('saved file', name)

# use this to download a file
def download(path):
  from google.colab import files
  files.download(path)

# %% [markdown]
# # Step 4: Run Detections with Darknet and YOLOv3!
# Darknet is now built and ready to run detections using YOLOv3 in the cloud! You can find out which sorts of classes the pretrained YOLOv3 weights can detect by clicking here. [COCO CLASSES](http://cocodataset.org/#explore)
#
# The object detector can be run using the following command
# ```bash
# !./darknet detect <path to config> <path to weights> <path to image>
# ```
# Darknet comes with a few images already installed in the darknet/data/ folder.
#
# **Note:** After running detections OpenCV can't open the image instantly in the cloud so we must run:
# ```bash
# imShow('predictions.jpg')
# ```
# This will output the image with the detections shown. The most recent detections are always saved to 'predictions.jpg'
#
# Try out the examples below for yourself!

# %%
# run darknet detection
# !./darknet detect cfg/yolov3.cfg yolov3.weights data/person.jpg
# Out:
# /bin/bash: line 1: ./darknet: Is a directory

# %%
# show image using our helper function
imShow('predictions.jpg')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-2f91a359050e> in <cell line: 2>()
#       1 # show image using our helper function
# ----> 2 imShow('predictions.jpg')
#
# <ipython-input-6-763537445f46> in imShow(path)
#       6
#       7   image = cv2.imread(path)
# ----> 8   height, width = image.shape[:2]
#       9   resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)
#      10
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
# look we can run another detection!
# !./darknet detect cfg/yolov3.cfg yolov3.weights data/dog.jpg
imShow('predictions.jpg')

# %% [markdown]
#  WOW this is magic! Make sure to click this link to be blessed with lots of YOLOv3 luck!!!
#  [https://www.youtube.com/channel/UCrydcKaojc44XnuXrfhlV8Q?sub_confirmation=1](https://www.youtube.com/channel/UCrydcKaojc44XnuXrfhlV8Q?sub_confirmation=1)

# %%
# This stops 'Run all' at this cell by causing an error
assert False

# %% [markdown]
# # Step 5: Uploading Local or Google Drive Files to Use
# You may want to run detections on more than just the images within the darknet/data/ folder. This step will show you how to upload local or Google Drive files to the cloud VM and run detections on them!

# %% [markdown]
# ### Method 1: Local Files
# To upload local files just use our helper function by running 'upload()' as seen below. Click **Choose Files** and select the image from your local machine that you want to upload to the cloud VM.
#
# If this function doesn't work for you then click the **Upload** button in the File Explorer on the left side of your notebook.
# ![image.png](data:image/png;base64,...)
#
#
# The image should save to your root directory so that you can access it from your darknet command by running.
# ```
# !./darknet detect cfg/yolov3.cfg yolov3.weights ../<your image name>
# ```

# %%
# upload an image to root directory (I uploaded an image called street.jpg, you can upload anything)
# %cd ..
upload()

# %%
# make sure you are in the darknet folder to run the detections command!
# %cd darknet
# !./darknet detect cfg/yolov3.cfg yolov3.weights ../street.jpg
imShow('predictions.jpg')

# %% [markdown]
# ### Method 2: Google Drive
# Images can also be uploaded from your Google Drive and easily have detections run on them.
#
# You will want to run the below cell to mount your google drive into the cloud VM so that you can access its contents. It is that easy!
#
# **NOTE:** We will be creating a symbolic link between '/content/gdrive/My\ Drive/' and '/mydrive.
#
# This means we are just creating a shortcut '/mydrive' to map to the contents within the folder '/content/gdrive/My\ Drive/'.
#
# The reason for this is that sometime having the space in 'My Drive' folder path can cause issues when running certain commands. This symbolic link will stop this from happening!
#
# Now you can run YOLOv3 with images from Google Drive using the darknet command:
# ```
# !./darknet detect cfg/yolov3.cfg yolov3.weights /mydrive/<path to image>
# ```
# I recommend saving images within a folder called 'images' at the root level of your Google Drive.

# %%
# %cd ..
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# /content

# %%
# this creates a symbolic link so that now the path /content/gdrive/My\ Drive/ is equal to /mydrive
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive

# %%
# run darknet command with google drive image (my image path is /images/plane.jpg)
# %cd darknet
# !./darknet detect cfg/yolov3.cfg yolov3.weights /mydrive/images/plane.jpg
imShow('predictions.jpg')
# Out:
# /content/darknet
#  CUDA-version: 12020 (12020), cuDNN: 8.9.6, GPU count: 1
#  OpenCV version: 4.5.4
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5,  wt = 0, wn = 0, outputs: 104 x 104 x 128 0.001 BF
#    9 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#   10 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#   11 Shortcut Layer: 8,  wt = 0, wn = 0, outputs: 104 x 104 x 128 0.001 BF
#   12 conv    256       3 x 3/ 2    104 x 104 x 128 ->   52 x  52 x 256 1.595 BF
#   13 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   14 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   15 Shortcut Layer: 12,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   16 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   17 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   18 Shortcut Layer: 15,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   19 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   20 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   21 Shortcut Layer: 18,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   22 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   23 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   24 Shortcut Layer: 21,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   25 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   26 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   27 Shortcut Layer: 24,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   28 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   29 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   30 Shortcut Layer: 27,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   31 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   32 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   33 Shortcut Layer: 30,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   34 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   35 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   36 Shortcut Layer: 33,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   37 conv    512       3 x 3/ 2     52 x  52 x 256 ->   26 x  26 x 512 1.595 BF
#   38 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   39 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   40 Shortcut Layer: 37,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   41 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   42 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   43 Shortcut Layer: 40,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   44 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   45 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   46 Shortcut Layer: 43,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   47 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   48 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   49 Shortcut Layer: 46,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   50 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   51 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   52 Shortcut Layer: 49,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   53 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   54 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   55 Shortcut Layer: 52,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   56 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   57 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   58 Shortcut Layer: 55,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   59 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   60 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   61 Shortcut Layer: 58,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   62 conv   1024       3 x 3/ 2     26 x  26 x 512 ->   13 x  13 x1024 1.595 BF
#   63 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   64 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   65 Shortcut Layer: 62,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   66 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   67 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   68 Shortcut Layer: 65,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   69 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   70 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   71 Shortcut Layer: 68,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   72 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   73 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   74 Shortcut Layer: 71,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   75 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   76 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   77 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   78 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   79 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   80 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   81 conv    255       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 255 0.088 BF
#   82 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
#   83 route  79 		                           ->   13 x  13 x 512
#   84 conv    256       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 256 0.044 BF
#   85 upsample                 2x    13 x  13 x 256 ->   26 x  26 x 256
#   86 route  85 61 	                           ->   26 x  26 x 768
#   87 conv    256       1 x 1/ 1     26 x  26 x 768 ->   26 x  26 x 256 0.266 BF
#   88 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   89 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   90 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   91 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   92 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   93 conv    255       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 255 0.177 BF
#   94 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
#   95 route  91 		                           ->   26 x  26 x 256
#   96 conv    128       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 128 0.044 BF
#   97 upsample                 2x    26 x  26 x 128 ->   52 x  52 x 128
#   98 route  97 36 	                           ->   52 x  52 x 384
#   99 conv    128       1 x 1/ 1     52 x  52 x 384 ->   52 x  52 x 128 0.266 BF
#  100 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#  101 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#  102 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#  103 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#  104 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#  105 conv    255       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 255 0.353 BF
#  106 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
# Total BFLOPS 65.879
# avg_outputs = 532444
#  Allocate additional workspace_size = 52.44 MB
# Loading weights from yolov3.weights...
#  seen 64, trained: 32013 K-images (500 Kilo-batches_64)
# Done! Loaded 107 layers from weights-file
# Cannot load image /mydrive/images/plane.jpg
#  Detection layer: 82 - type = 28
#  Detection layer: 94 - type = 28
#  Detection layer: 106 - type = 28
# /mydrive/images/plane.jpg: Predicted in 1820.273000 milli-seconds.
# OpenCV exception: show_image_cv

# %% [markdown]
# ### Download Files to Local Machine or Google Drive from Cloud VM
# You can also easily download images from your cloud VM to save to your local machine or Google Drive.
#
# #### Method 1: Local Machine
#
# You can do it easily by using our helper function 'download()' or by right clicking the image in the File Explorer on the left side of your notebook and hitting **Download**. Files will be saved to your *Downloads* folder.
#
# This is useful if you want to download the **'predictions.jpg'** images that the object detector outputs.
#
# #### Method 2: Google Drive
# A simple copy command can copy over any file to your Google Drive as it is already mounted. (you must run the mount command above if you have not already)
#
# ```
# !cp <file to download> <destination to save file>
# ```
# See example of each below!

# %%
# LOCAL MACHINE DOWNLOAD
# if you get an error first run then run it again and it should work
download('predictions.jpg')

# %%
# GOOGLE DRIVE DOWNLOAD
# note that I can change what the image name is saved as (I am saving it as detection1.jpg)
# !cp predictions.jpg /mydrive/images/detection1.jpg

# %% [markdown]
# # Training a Custom YOLOv3 Object Detector in the Cloud!
# Now comes the fun part! It is time to create your very own custom object detector, all within the cloud for free! The options are endless for what objects/classes you can make your detector detect. So think of something creative or just follow along with what I create. It is up to you!
#
# **WOW! YOU ARE KILLING IT SO FAR!**
#
# This requires a couple tricks and tips so make sure to follow along closely with the rest of the tutorial.
#
# In order to create a custom YOLOv3 detector we will need the following:
#
# *   Labeled Custom Dataset
# *   Custom .cfg file
# *   obj.data and obj.names files
# *   train.txt file (test.txt is optional here as well)

# %% [markdown]
# # Step 1: Gathering and Labeling a Custom Dataset
# In order to create a custom object detector you need a good dataset of images and labels so that the detector can be efficiently trained to detect objects.
#
# This can be done in two ways. through  or through using Google images or creating your own dataset and using an annotation tool to manually draw labels. **(I recommend the first way!)**

# %% [markdown]
# ### Method 1: Using Google's Open Images Dataset (RECOMMENDED)
# This method is the method I recommend as you can gather thousands of images and auto-generate their labels within minutes! Gathering a dataset from Google's Open Images Dataset and using OIDv4 toolkit to generate labels is easy and time efficient. The dataset contains labeled images for over 600 classes! [Explore the Dataset Here!](https://storage.googleapis.com/openimages/web/index.html)
#
# Watch one of my previous youtube videos on how to do use this approach to create your own custom dataset!
#
# [Creating a Custom YOLOv3 Dataset (Video)](https://www.youtube.com/watch?v=_4A9inxGqRM)
#
# Here is a link to my github repository for the OIDv4 toolkit! [Github Repo](https://github.com/theAIGuysCode/OIDv4_ToolKit)
#
# For this tutorial I will be creating a safari animal object detector using data from Google's Open Images Dataset. I ran the following commands within the toolkit.
# ```
# python main.py downloader --classes Elephant Giraffe Hippopotamus Tiger Zebra --type_csv train --limit 300 --multiclasses 1
# ```
# This creates a folder with 300 images for each of Elephant, Giraffe, Hippopotamus, Tiger, and Zebra images. So 1500 images in total and saves them all to one folder.
#
# Within the root OIDv4_ToolKit folder open the file classes.txt and edit it to have the classes you just downloaded, one per line.
# ![image.png](data:image/png;base64,...)
#
# Now convert the image annotations:
# ```
# python convert_annotations.py
# ```
# This converts all labels to YOLOv3 format which can now be used by darknet to properly train our custom object detector.
#
# Remove the old 'Label' folder in the OIDv4 toolkit which contains the non YOLOv3 formatted labels by running: (your file path will have a different name for Elephant_Giraffe.. depending on which classes you downloaded.
# ```
# rm -r OID/Dataset/train/Elephant_Giraffe_Hippopotamus_Tiger_Zebra/Label/
# ```
# If this command doesn't work on your machine then just go to the folder with 'Label' and right click and hit **Delete** to manually delete it.
#
# The folder with all your images and annotations should now look like this. Each image should have a text file with the same name.
# ![image.png](data:image/png;base64,...)
#
# ## You have sucessfully generated a custom YOLOv3 dataset! Congrats!

# %% [markdown]
# ### Method 2: Manually Labeling Images with Annotation Tool
# If you can't find the proper images or classes within Google's Open Images Dataset then you will have to use an annotation tool to manually draw your labels which can be a tiresome process.
#
# I have created a previous video where I walk through how to mass download images from Google Images along with how to use LabelImg, an annotation tool, in order to create a custom dataset for YOLOv3. Hit link below to learn how.
#
# [Create Labels and Annotations for Custom YOLOv3 Dataset (Video)](https://www.youtube.com/watch?v=EGQyDla8JNU)
#
# After following the tutorial video you should now have a folder with images and text files like the one above.
#
# ## You have successfully generated a custom YOLOv3 dataset! Congrats!

# %% [markdown]
# # Step 2: Moving Your Custom Dataset Into Your Cloud VM
# So now that you have your dataset properly formatted to be used for training we need to move it into this cloud VM so that when it comes the time we can actually use it for training.
#
# I recommend renaming the folder with your images and text files on your local machine to be called '**obj**' and then creating a .zip folder of the 'obj' folder. Then I recommend uploading the zip to your Google Drive. So you should now have obj.zip someplace in your Google drive.
#
# This will **greatly reduce** the time it takes to transfer our dataset into our cloud VM.
#
# Now we can copy in the zip and unzip it on your cloud VM.

# %%
# this is where my zip is stored (I created a yolov3 folder where I will get my required files from)
# !ls /mydrive/yolov3
# Out:
#  backup		     obj.data.gdoc    OIP.jpeg			    yolov3_custom.cfg.gdoc
#  generate_train.py   obj.names	     'yolov3_custom (1).cfg.gdoc'   yolov3_custom_last.weights
#  image_test	     obj.names.gdoc   yolov3_custom2.cfg
#  obj.data	     obj.zip	      yolov3_custom.cfg

# %%
# copy the .zip file into the root directory of cloud VM
# !cp /mydrive/yolov3/obj.zip ../

# %%
# unzip the zip file and its contents should now be in /darknet/data/obj
# !unzip ../obj.zip -d data/
# Out:
# Archive:  ../obj.zip
#    creating: data/merge/Knife_Handgun_Shotgun/
#   inflating: data/merge/Knife_Handgun_Shotgun/00001bcc92282a38.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/00001bcc92282a38.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/00009cadede2ed69.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/00009cadede2ed69.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0002f32727ed756e.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0002f32727ed756e.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/000305928f7b43da.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/000305928f7b43da.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0005451344f10814.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0005451344f10814.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0005b2913ba46ddf.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0005b2913ba46ddf.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0009f11d5e2d0e40.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0009f11d5e2d0e40.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/00141962b7815d54.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/00141962b7815d54.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/001995cd6c6cbbe2.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/001995cd6c6cbbe2.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/001a7118d6df8b18.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/001a7118d6df8b18.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0027b445b545ae1c.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0027b445b545ae1c.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0030b3c791b172ae.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0030b3c791b172ae.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/003228bcad10445e.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/003228bcad10445e.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/00329773aa14e3ad.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/00329773aa14e3ad.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/003af63a783a1615.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/003af63a783a1615.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/003d22c8b3ba23c2.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/003d22c8b3ba23c2.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/003e17bf335ca518.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/003e17bf335ca518.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/00459f3bf70283d3.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/00459f3bf70283d3.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0045a7e07dd4fa0e.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0045a7e07dd4fa0e.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/004eb6ca27183afe.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/004eb6ca27183afe.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/004f4b4f5b0d4495.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/004f4b4f5b0d4495.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/005271fd61c99a0b.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/005271fd61c99a0b.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/006000750bff4f86.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/006000750bff4f86.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/006165f00fc70180.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/006165f00fc70180.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0065a51ab60e59fe.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0065a51ab60e59fe.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0065a9f1ac8ca2b4.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0065a9f1ac8ca2b4.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/006a4616b35cf5db.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/006a4616b35cf5db.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/006aba5f64962861.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/006aba5f64962861.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/006fb86aed487201.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/006fb86aed487201.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/006fd953d2fb5221.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/006fd953d2fb5221.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0074b30cead571bb.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0074b30cead571bb.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0075bcaef3de1f81.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0075bcaef3de1f81.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0079ef151c5bb5b5.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0079ef151c5bb5b5.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/007bee44fe46df07.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/007bee44fe46df07.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0091ee1e42ca00f7.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0091ee1e42ca00f7.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/00c04a1be1f153f0.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/00c04a1be1f153f0.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/00c539777dc025be.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/00c539777dc025be.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/00d1e939c70f17f0.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/00d1e939c70f17f0.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/00d68dc021f3c8e5.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/00d68dc021f3c8e5.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/00d71b0afcf0e508.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/00d71b0afcf0e508.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/00d7a87067115e88.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/00d7a87067115e88.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/00df6076ebb98b03.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/00df6076ebb98b03.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/00e0624e3475ed11.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/00e0624e3475ed11.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/00e57fff9d65a8a2.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/00e57fff9d65a8a2.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/00e5eb7fe4a2db73.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/00e5eb7fe4a2db73.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/00e71dd7bd07a35d.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/00e71dd7bd07a35d.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/00ea275ed618deb0.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/00ea275ed618deb0.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/00ec951800b3058e.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/00ec951800b3058e.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/00f4ec9ee8901d37.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/00f4ec9ee8901d37.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/01008e1fc52a5f36.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/01008e1fc52a5f36.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/01058754bcb30fa1.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/01058754bcb30fa1.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/010dce7cb9251d5e.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/010dce7cb9251d5e.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/010fc688dbee9670.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/010fc688dbee9670.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/011c5fc3ceab6483.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/011c5fc3ceab6483.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/012333f9c7fadce2.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/012333f9c7fadce2.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/01256417e9026eaf.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/01256417e9026eaf.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/012621161af4bae3.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/012621161af4bae3.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0126937d9e15b7c6.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0126937d9e15b7c6.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0127cf8617e6b52f.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0127cf8617e6b52f.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/012dcd050f403cd9.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/012dcd050f403cd9.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0137710960addb4e.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0137710960addb4e.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/013bc45321bef9c3.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/013bc45321bef9c3.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/013eeb549831a5c5.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/013eeb549831a5c5.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0148c4e77ea54960.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0148c4e77ea54960.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/015cd5353344d722.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/015cd5353344d722.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/016f96522808c092.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/016f96522808c092.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0174388f19e14c32.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0174388f19e14c32.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/01782b33668edf82.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/01782b33668edf82.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/017c8de936318a81.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/017c8de936318a81.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/018b5ee882162019.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/018b5ee882162019.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/018d4a117c1d7e16.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/018d4a117c1d7e16.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/01903b1621080721.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/01903b1621080721.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/019cec23acf63d5a.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/019cec23acf63d5a.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/01a6ef2ebff837d3.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/01a6ef2ebff837d3.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/01b9021aa05e6e46.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/01b9021aa05e6e46.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/01cf8125a27d477b.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/01cf8125a27d477b.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/01d0ba02a5b97d5c.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/01d0ba02a5b97d5c.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/01d8ae234911f72d.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/01d8ae234911f72d.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/01d98277571fe017.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/01d98277571fe017.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/01f5f240dbc056f9.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/01f5f240dbc056f9.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/01f672d2cf8bfbac.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/01f672d2cf8bfbac.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/01fdd21ac29706bc.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/01fdd21ac29706bc.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/02026c76bde7e6ea.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/02026c76bde7e6ea.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0209905ab6725662.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0209905ab6725662.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0209f11cc23fd47e.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0209f11cc23fd47e.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/020ebd74309b827d.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/020ebd74309b827d.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0231d2f11eb7a483.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0231d2f11eb7a483.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0232e0688844b729.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0232e0688844b729.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/02363431c89e4f7c.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/02363431c89e4f7c.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0244f25e476ff7ba.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0244f25e476ff7ba.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0255c5b642987e73.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0255c5b642987e73.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/025ae0153cba502f.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/025ae0153cba502f.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/02617d55d41e90a1.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/02617d55d41e90a1.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0270d602ff3f3151.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0270d602ff3f3151.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0275ceffe6052be8.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0275ceffe6052be8.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/027c5d8272d87b32.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/027c5d8272d87b32.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/02882d25edb5f06f.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/02882d25edb5f06f.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/028d68c9bfcbc360.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/028d68c9bfcbc360.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/02925351bb3ca378.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/02925351bb3ca378.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0299ca3a493f3002.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0299ca3a493f3002.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/029bb6e673425f20.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/029bb6e673425f20.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/02a80c4e24674f53.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/02a80c4e24674f53.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/02c3f9f98c94ee0f.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/02c3f9f98c94ee0f.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/02c6e0ff5cbbcc63.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/02c6e0ff5cbbcc63.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/02ccde225a936a96.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/02ccde225a936a96.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/02d97c9c74818c14.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/02d97c9c74818c14.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/02e3e9a3bdeae9fb.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/02e3e9a3bdeae9fb.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/02e777ca05730e04.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/02e777ca05730e04.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/02ea4cd9da09abce.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/02ea4cd9da09abce.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/02ea4f631efee116.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/02ea4f631efee116.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/02eec2c28f8cdb8e.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/02eec2c28f8cdb8e.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/02eff940ae3f0189.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/02eff940ae3f0189.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/02f9ae767bfcf239.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/02f9ae767bfcf239.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/02fc017b3c216bfe.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/02fc017b3c216bfe.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0304ad7f7fe22b23.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0304ad7f7fe22b23.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/030918a2abf658f3.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/030918a2abf658f3.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0315e60e498caa4c.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0315e60e498caa4c.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0318125dfa3cf007.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0318125dfa3cf007.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/031d6d549493c55e.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/031d6d549493c55e.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0320662d45d55cdf.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0320662d45d55cdf.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/032d284c9e52a9fa.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/032d284c9e52a9fa.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/03576a6eb56fa4a6.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/03576a6eb56fa4a6.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0366a3352e8affd0.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0366a3352e8affd0.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/036cced2d11ec245.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/036cced2d11ec245.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/038733c09c810ec7.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/038733c09c810ec7.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/039f27ac12c793bb.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/039f27ac12c793bb.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/03a76011de8d470a.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/03a76011de8d470a.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/03d51a7823b79dfc.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/03d51a7823b79dfc.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/03de9e04639fc3f4.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/03de9e04639fc3f4.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/03e4bb9a4c3685b7.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/03e4bb9a4c3685b7.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/03eedc5e87e43eb8.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/03eedc5e87e43eb8.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/03f58d4588cfbc81.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/03f58d4588cfbc81.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/03f6288f49430b0c.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/03f6288f49430b0c.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/040b7dcf6ee16b92.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/040b7dcf6ee16b92.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0413d1bfeb05ba12.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0413d1bfeb05ba12.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/041d87b6266faa8e.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/041d87b6266faa8e.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/041ec0633447b467.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/041ec0633447b467.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0424cbc162bcd2f9.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0424cbc162bcd2f9.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/043901ff86ea73aa.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/043901ff86ea73aa.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0443405892fa306a.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0443405892fa306a.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/04453c7b2a60dc3d.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/04453c7b2a60dc3d.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/044b569c3ba18575.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/044b569c3ba18575.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/04543230800dac0d.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/04543230800dac0d.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/047130dfa480f390.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/047130dfa480f390.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0488fd6b207f203a.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0488fd6b207f203a.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/048cb4cff077fd42.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/048cb4cff077fd42.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/04970ac1c9d4b54e.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/04970ac1c9d4b54e.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0498e6dffb2e773d.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0498e6dffb2e773d.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/04abf880fdee279d.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/04abf880fdee279d.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/04d1941693ead454.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/04d1941693ead454.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/04d6206483f835e6.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/04d6206483f835e6.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/04d86cd21bcda1f1.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/04d86cd21bcda1f1.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/050888641f95caa7.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/050888641f95caa7.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/051545e07a1f8eaa.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/051545e07a1f8eaa.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/051ed63d53944b48.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/051ed63d53944b48.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0527ddf0ce2aa83e.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0527ddf0ce2aa83e.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0545729b8c3f31cf.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0545729b8c3f31cf.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/05464a22589cd60d.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/05464a22589cd60d.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/054744d67fdc06ba.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/054744d67fdc06ba.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/054867d71726756e.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/054867d71726756e.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/05495f53f7872c78.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/05495f53f7872c78.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/05582daf6814b091.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/05582daf6814b091.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0560936240ced314.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0560936240ced314.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0560ebb954bb8a81.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0560ebb954bb8a81.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0565bcccb1266f62.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0565bcccb1266f62.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/056e6614fb985947.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/056e6614fb985947.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/057ed7c0ee6c035b.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/057ed7c0ee6c035b.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/058dd78ea5867506.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/058dd78ea5867506.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0594ecef74729d71.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0594ecef74729d71.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/05a0dd0133e1c360.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/05a0dd0133e1c360.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/05a1795e83200966.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/05a1795e83200966.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/05a2b5465ae39b43.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/05a2b5465ae39b43.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/05a7a5b042419839.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/05a7a5b042419839.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/05b775285c85478a.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/05b775285c85478a.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/05cee6e5f0497086.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/05cee6e5f0497086.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/05d456e48ea9892e.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/05d456e48ea9892e.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/05ef9906a404669b.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/05ef9906a404669b.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/05fa17455bde44bc.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/05fa17455bde44bc.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0600f88efab6d790.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0600f88efab6d790.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0602cd5998096480.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0602cd5998096480.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0610e5b04587bea4.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0610e5b04587bea4.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/063e222536989bc2.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/063e222536989bc2.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0645f4ac8d6dc868.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0645f4ac8d6dc868.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/064d2f3f23c6e90e.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/064d2f3f23c6e90e.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/065c7e3482399cfb.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/065c7e3482399cfb.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/066c17210ae80c4a.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/066c17210ae80c4a.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0678842cb5745a0b.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0678842cb5745a0b.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/067a6252cdd1c887.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/067a6252cdd1c887.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/068fb4b25469c4d0.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/068fb4b25469c4d0.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/06cbcde12cc2f58f.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/06cbcde12cc2f58f.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/06e79c13400643e2.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/06e79c13400643e2.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/06f860c6e7b5559f.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/06f860c6e7b5559f.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0704e0466219ab24.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0704e0466219ab24.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0714ba87e14391c7.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0714ba87e14391c7.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/072dd9c51439ae62.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/072dd9c51439ae62.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/074823afff4f524e.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/074823afff4f524e.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/07623a52364584e3.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/07623a52364584e3.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/07777b3ccd457a4b.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/07777b3ccd457a4b.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/077baa4e85a2ece1.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/077baa4e85a2ece1.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/078137c87ab2c4d0.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/078137c87ab2c4d0.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/078fb48c94eb245c.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/078fb48c94eb245c.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/07b2eeede5b0c02d.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/07b2eeede5b0c02d.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/07fc1249f87750e7.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/07fc1249f87750e7.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/08301e4b31f8b73b.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/08301e4b31f8b73b.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/085040b844c2aa92.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/085040b844c2aa92.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/085622859f9b4eb2.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/085622859f9b4eb2.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/086121e3ec099a94.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/086121e3ec099a94.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/08671d838f028181.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/08671d838f028181.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0872eaf3283800bc.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0872eaf3283800bc.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/088519ae8d56c4e6.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/088519ae8d56c4e6.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/088af1925dd38378.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/088af1925dd38378.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/089ed123cb0eee58.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/089ed123cb0eee58.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/08b07350225e5ace.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/08b07350225e5ace.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/08c33dc01dce3239.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/08c33dc01dce3239.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/08d1868f368d2b55.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/08d1868f368d2b55.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/08d7adec77778b7a.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/08d7adec77778b7a.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/08e1d5e8f4d2cb9e.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/08e1d5e8f4d2cb9e.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/08ec9988804c49bd.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/08ec9988804c49bd.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/09061212bc38d3c7.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/09061212bc38d3c7.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/090897e8ebc8adf5.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/090897e8ebc8adf5.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/090e1a5934783118.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/090e1a5934783118.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0917b43e798cbd64.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0917b43e798cbd64.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/091c67d8ecf9c99d.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/091c67d8ecf9c99d.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/09383bdb52bfc8be.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/09383bdb52bfc8be.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/093cdad8aaf111b3.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/093cdad8aaf111b3.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/094b93f96fd1a92c.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/094b93f96fd1a92c.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/095097022580c38a.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/095097022580c38a.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/095dcc6f1d086172.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/095dcc6f1d086172.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/095ee3436e64f0ec.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/095ee3436e64f0ec.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/096c39dfb17068cf.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/096c39dfb17068cf.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/096d564e76815aaa.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/096d564e76815aaa.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0970162c4b382ea0.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0970162c4b382ea0.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/09742a38781f6492.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/09742a38781f6492.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0977e7e687bafb92.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0977e7e687bafb92.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/098883b5047486f2.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/098883b5047486f2.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/09898b1c695f74f7.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/09898b1c695f74f7.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/09a9a9d1fe0a592a.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/09a9a9d1fe0a592a.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/09b182dbd97b604c.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/09b182dbd97b604c.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/09b4b3d0008c9191.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/09b4b3d0008c9191.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/09b7c98fd2a64132.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/09b7c98fd2a64132.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/09bfb6ea7846181a.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/09bfb6ea7846181a.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0a01bacf8d0664b9.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0a01bacf8d0664b9.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0a02b68e8cfd4af9.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0a02b68e8cfd4af9.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0a16050e1925341c.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0a16050e1925341c.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0a16f91d30c34f61.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0a16f91d30c34f61.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0a4579d3deb36479.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0a4579d3deb36479.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0a46f9b3afe642f2.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0a46f9b3afe642f2.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0a4a34cff82148b5.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0a4a34cff82148b5.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0a6de9d0d9692797.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0a6de9d0d9692797.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0a7183bbd46641d7.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0a7183bbd46641d7.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0a74aa802283e060.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0a74aa802283e060.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0a765ae3ad3b9ec8.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0a765ae3ad3b9ec8.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0a7a9e434ba275e3.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0a7a9e434ba275e3.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0a7dd973336999df.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0a7dd973336999df.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0a81306a4f77c265.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0a81306a4f77c265.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0a82da55ed950074.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0a82da55ed950074.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0a983247f6a0b9bd.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0a983247f6a0b9bd.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0aa8727faf4ae1cf.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0aa8727faf4ae1cf.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0ab957426db1e760.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0ab957426db1e760.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0b019f09f1189536.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0b019f09f1189536.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0b1219fded94d150.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0b1219fded94d150.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0b261b614f40b559.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0b261b614f40b559.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0b2c4310d5629e70.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0b2c4310d5629e70.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0b9238b5cf124731.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0b9238b5cf124731.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0bb77d79af53a581.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0bb77d79af53a581.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0bbffd2d0a4a719d.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0bbffd2d0a4a719d.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0bc3782017592f12.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0bc3782017592f12.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0bd63662e7cd0810.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0bd63662e7cd0810.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0bef4f89b589f0b4.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0bef4f89b589f0b4.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0c2ac1c54dfd3466.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0c2ac1c54dfd3466.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0c4b629e801e8181.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0c4b629e801e8181.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0c4ef283cb2d7be0.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0c4ef283cb2d7be0.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0c595e04b77f3031.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0c595e04b77f3031.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0c6986ed7b68928c.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0c6986ed7b68928c.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0c73b72d82c32b12.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0c73b72d82c32b12.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0c87545ba250f18c.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0c87545ba250f18c.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0caad617044daefb.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0caad617044daefb.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0cbe70d298dc8cc0.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0cbe70d298dc8cc0.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0cc3124a3238341f.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0cc3124a3238341f.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0cc98323ed2e4fc5.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0cc98323ed2e4fc5.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0cdd0ec962783d23.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0cdd0ec962783d23.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0cdf74810d6c9e2f.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0cdf74810d6c9e2f.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0cdfe048019a899c.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0cdfe048019a899c.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0d232a2d6ad4eed5.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0d232a2d6ad4eed5.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0d25f1cf15f5b3b4.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0d25f1cf15f5b3b4.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0d3778d01cc38bb9.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0d3778d01cc38bb9.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0d3f3f4e0634026b.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0d3f3f4e0634026b.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0d46cdefc930e6e9.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0d46cdefc930e6e9.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0d4986b545f98b96.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0d4986b545f98b96.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0d7f4abd8b3cb643.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0d7f4abd8b3cb643.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0d854d62b14b9b92.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0d854d62b14b9b92.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0d98fcdd5e425cf9.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0d98fcdd5e425cf9.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0d99c690df7bb90e.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0d99c690df7bb90e.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0da8356816714813.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0da8356816714813.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0dca85a81d729ddb.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0dca85a81d729ddb.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0e0334cfa09a4637.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0e0334cfa09a4637.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0e048a4f911279f4.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0e048a4f911279f4.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0e42733e2e82b4a2.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0e42733e2e82b4a2.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0e6275396999530d.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0e6275396999530d.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0e7cee5235313fbe.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0e7cee5235313fbe.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0e7d5f8b921d4fd2.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0e7d5f8b921d4fd2.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0e8a5a9efc693cf5.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0e8a5a9efc693cf5.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0ea1255bbe3ddb30.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0ea1255bbe3ddb30.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0ea79ece19320efe.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0ea79ece19320efe.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0eb9e572cf930fc7.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0eb9e572cf930fc7.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0ebc51aea0d8fcb4.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0ebc51aea0d8fcb4.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0ec2cd87cca025c5.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0ec2cd87cca025c5.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0ef93fea82e59b65.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0ef93fea82e59b65.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0f1a5125f801251b.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0f1a5125f801251b.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0f22eaf0d420239f.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0f22eaf0d420239f.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0f313ae45126e3dc.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0f313ae45126e3dc.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0f3a8d79829e0af1.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0f3a8d79829e0af1.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0f50833cd8bcbee6.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0f50833cd8bcbee6.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0f5eec3235d8a3df.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0f5eec3235d8a3df.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0f9cde9b86c937f5.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0f9cde9b86c937f5.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0faa94bec638caab.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0faa94bec638caab.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0fd074fdd8166f9b.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0fd074fdd8166f9b.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/0febb7276ea9fe5f.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/0febb7276ea9fe5f.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/101caa9aa5457a4f.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/101caa9aa5457a4f.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/10413067e2b88fdf.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/10413067e2b88fdf.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/106e029772d694a7.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/106e029772d694a7.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/10901307d78e4e62.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/10901307d78e4e62.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/10acbbd6db8862cf.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/10acbbd6db8862cf.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/10bb17fe71f55a0c.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/10bb17fe71f55a0c.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/10bcc2ecfd75244a.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/10bcc2ecfd75244a.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/10e60d62fb9d6c6a.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/10e60d62fb9d6c6a.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/10fdc831420b8968.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/10fdc831420b8968.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/110c3d46f72b6dd3.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/110c3d46f72b6dd3.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/114eac58d70e8c7c.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/114eac58d70e8c7c.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/1194132584fa4ba2.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/1194132584fa4ba2.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/11beeac9eb9414af.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/11beeac9eb9414af.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/11c25413a421009c.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/11c25413a421009c.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/11e44bc68ae5071c.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/11e44bc68ae5071c.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/1203af37e4dc67ac.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/1203af37e4dc67ac.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/121d407874aac6c5.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/121d407874aac6c5.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/1228bfe2f3dc2d29.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/1228bfe2f3dc2d29.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/122977ac631623a9.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/122977ac631623a9.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/1238ac292c14feec.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/1238ac292c14feec.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/1239fa40eecbb506.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/1239fa40eecbb506.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/126cab8e28f78d29.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/126cab8e28f78d29.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/126fecdb21e1b1d7.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/126fecdb21e1b1d7.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/1297b6d1a741ad0a.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/1297b6d1a741ad0a.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/12a8dd7fa9629e71.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/12a8dd7fa9629e71.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/12b8dfc8024923fe.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/12b8dfc8024923fe.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/12b9323540615016.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/12b9323540615016.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/12ba53bad2db1856.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/12ba53bad2db1856.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/12cfc3b2a7ce909b.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/12cfc3b2a7ce909b.txt
# ...
#   inflating: data/merge/Knife_Handgun_Shotgun/a2b5188ba29e3245.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/a6dd3fce67c70565.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/a6dd3fce67c70565.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/a72960fa1ee6eecd.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/a72960fa1ee6eecd.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/a96929cd15c990c4.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/a96929cd15c990c4.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/a9bf5cacd31b72ef.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/a9bf5cacd31b72ef.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/aab2de24a5b7521a.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/aab2de24a5b7521a.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/aab5f2158ebe0d74.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/aab5f2158ebe0d74.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/ab80de5a58b9ccd0.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/ab80de5a58b9ccd0.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/ac169ff71a3748ba.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/ac169ff71a3748ba.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/ad559c3c6afb0471.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/ad559c3c6afb0471.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/ae1e5fe814d7d1d7.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/ae1e5fe814d7d1d7.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/ae5aba73dba01c43.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/ae5aba73dba01c43.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/ae8dfae27d0e9820.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/ae8dfae27d0e9820.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/aea45ba75eb06f5c.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/aea45ba75eb06f5c.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/af403410b6934966.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/af403410b6934966.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/afd58b401e8d3bc5.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/afd58b401e8d3bc5.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/b21f21087356d8e0.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/b21f21087356d8e0.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/b3bc9f4e892b9bc4.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/b3bc9f4e892b9bc4.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/b43ef4680b3ba5c8.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/b43ef4680b3ba5c8.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/b451e7ba8a09352f.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/b451e7ba8a09352f.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/b4aa4ea0b5de9e02.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/b4aa4ea0b5de9e02.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/b4d228216f60ebab.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/b4d228216f60ebab.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/b565c7b6613dc723.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/b565c7b6613dc723.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/b6fa368bf4945b7a.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/b6fa368bf4945b7a.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/b780b4e25bb6ca8a.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/b780b4e25bb6ca8a.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/ba5898ce6bc120f8.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/ba5898ce6bc120f8.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/bad048e285e2cab3.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/bad048e285e2cab3.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/bafd801621510353.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/bafd801621510353.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/bc5811d3a4bff02f.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/bc5811d3a4bff02f.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/bc857cdddd5c152e.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/bc857cdddd5c152e.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/beb5e12fd1db5c16.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/beb5e12fd1db5c16.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/bf0ad1c2a08e14b3.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/bf0ad1c2a08e14b3.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/c0818fa38d34f5cd.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/c0818fa38d34f5cd.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/c2467bc69c13df19.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/c2467bc69c13df19.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/c28ec01703f01d4c.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/c28ec01703f01d4c.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/c2c22e2cd5f3a11a.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/c2c22e2cd5f3a11a.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/c344f39e0518376a.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/c344f39e0518376a.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/c37520cdeeaed440.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/c37520cdeeaed440.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/c411615719633555.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/c411615719633555.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/c60a1e293ef52ee3.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/c60a1e293ef52ee3.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/c63656d2b3fa4a76.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/c63656d2b3fa4a76.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/c6a7016c62ecf311.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/c6a7016c62ecf311.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/c6e573d1100602f2.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/c6e573d1100602f2.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/c78c7e7adba3a81d.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/c78c7e7adba3a81d.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/c78d74060842b8f0.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/c78d74060842b8f0.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/c7c3b5fca2bb65fa.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/c7c3b5fca2bb65fa.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/ca496701f5bb00f1.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/ca496701f5bb00f1.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/ca7b477dcbdb91cd.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/ca7b477dcbdb91cd.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/ca8c48ccc6ac200a.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/ca8c48ccc6ac200a.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/cabc2340d8d386fc.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/cabc2340d8d386fc.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/cc51d7553cd390e3.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/cc51d7553cd390e3.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/ccff9094e269d824.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/ccff9094e269d824.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/cdee50717f906f4d.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/cdee50717f906f4d.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/cecb119df9f3e9d3.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/cecb119df9f3e9d3.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/cf024879ea396819.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/cf024879ea396819.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/cfee24c7b271dff6.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/cfee24c7b271dff6.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/d0c655a3d6b1760e.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/d0c655a3d6b1760e.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/d14f4e6e31474085.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/d14f4e6e31474085.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/d1e5138e3f47ecee.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/d1e5138e3f47ecee.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/d1f130ccb972f9d2.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/d1f130ccb972f9d2.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/d302a224a0cf1ff7.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/d302a224a0cf1ff7.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/d4920ecc69b60d09.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/d4920ecc69b60d09.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/d4b30cd7e57edb4b.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/d4b30cd7e57edb4b.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/d65bfe9f04fe612b.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/d65bfe9f04fe612b.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/d65dbc7824e1c960.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/d65dbc7824e1c960.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/d72f34fe24ca6320.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/d72f34fe24ca6320.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/d77ab3c1a4b13e5c.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/d77ab3c1a4b13e5c.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/d867a12dab45a459.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/d867a12dab45a459.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/dc84175596b5f4c7.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/dc84175596b5f4c7.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/dcafa14180e4e0e6.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/dcafa14180e4e0e6.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/ddba6c84ada96d2b.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/ddba6c84ada96d2b.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/ddfb26f1e3fe6b1f.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/ddfb26f1e3fe6b1f.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/df084aabc9a4bf4b.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/df084aabc9a4bf4b.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/dfab4e0d6a20f946.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/dfab4e0d6a20f946.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/e0a5d4a38f629f58.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/e0a5d4a38f629f58.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/e0dc90a20648d735.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/e0dc90a20648d735.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/e1b30ffa9cf66a20.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/e1b30ffa9cf66a20.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/e1f2937a9d457b15.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/e1f2937a9d457b15.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/e2959571ceda5447.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/e2959571ceda5447.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/e30963af22098cb8.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/e30963af22098cb8.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/e37b7c9eb6048c0a.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/e37b7c9eb6048c0a.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/e432f98cd3f48415.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/e432f98cd3f48415.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/e4914d398f505a48.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/e4914d398f505a48.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/e547672600381540.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/e547672600381540.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/e58f977d2ffa6585.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/e58f977d2ffa6585.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/e62df1a34b4e26b8.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/e62df1a34b4e26b8.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/e9b6333284bec5b5.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/e9b6333284bec5b5.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/e9b781944b676783.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/e9b781944b676783.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/ecfd84877d8c9668.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/ecfd84877d8c9668.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/ed6a5e4e1fd7c08a.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/ed6a5e4e1fd7c08a.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/ee4c1882bf2015a2.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/ee4c1882bf2015a2.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/eeb2a4cce446d5be.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/eeb2a4cce446d5be.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/eee0fb20f1d036db.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/eee0fb20f1d036db.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/f09a3380ee954ad2.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/f09a3380ee954ad2.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/f2a2a1a0095f5d79.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/f2a2a1a0095f5d79.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/f3276b944bbb9874.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/f3276b944bbb9874.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/f34a0b92a975f4e7.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/f34a0b92a975f4e7.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/f3afe69753018cae.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/f3afe69753018cae.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/f3e925aaa5e98689.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/f3e925aaa5e98689.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/f4231e6145333237.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/f4231e6145333237.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/f4fa3fdc618e32ab.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/f4fa3fdc618e32ab.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/f67398a103678840.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/f67398a103678840.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/f7134cbbe2458570.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/f7134cbbe2458570.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/f7af10c075265b6e.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/f7af10c075265b6e.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/f7b0da3e1000cd3b.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/f7b0da3e1000cd3b.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/f842b61569b8dba7.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/f842b61569b8dba7.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/f862a8347f9611ab.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/f862a8347f9611ab.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/f8e952ca788c0e41.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/f8e952ca788c0e41.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/fa4c4e5b92cd3cb2.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/fa4c4e5b92cd3cb2.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/faa37eb10c33a297.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/faa37eb10c33a297.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/fadf2fa731a45de6.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/fadf2fa731a45de6.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/fb3948655bb5f85f.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/fb3948655bb5f85f.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/fc24651a59daa65b.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/fc24651a59daa65b.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/fc330a763e13995f.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/fc330a763e13995f.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/fc8f5f9c3e2fc9f0.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/fc8f5f9c3e2fc9f0.txt
#   inflating: data/merge/Knife_Handgun_Shotgun/fd909fb9e01535a0.jpg
#   inflating: data/merge/Knife_Handgun_Shotgun/fd909fb9e01535a0.txt

# %% [markdown]
# # Step 3: Configuring Files for Training
# This step involves properly configuring your custom .cfg file, obj.data, obj.names and train.txt file.
#
# I have a detailed video on how to properly configure all four of these files to train a custom yolov3 detector. I will spare the time and ask you to watch the video in order to properly learn how to prepare the files.
#
# You can access the video with this link! [Configuring YOLOv3 Files for Training](https://www.youtube.com/watch?v=zJDUhGL26iU&t=300s)
#
# ## i) Cfg File
# Copy over the yolov3.cfg to edit by running the cell below.

# %%
# download cfg to google drive and change its name
# !cp cfg/yolov3.cfg /mydrive/yolov3/yolov3_custom2.cfg

# %%
# to download to local machine (change its name to yolov3_custom.cfg once you download)
download('cfg/yolov3.cfg')

# %% [markdown]
# Now you need to edit the .cfg to fit your needs based on your object detector. Open it up in a code or text editor to do so.
#
# If you downloaded cfg to google drive you can use the built in  **Text Editor** by going to your google drive and double clicking on yolov3_custom.cfg and then clicking on the **Open with** drop down and selectin **Text Editor**.
# ![image.png](data:image/png;base64,...)
#
# I recommend having **batch = 64** and **subdivisions = 16** for ultimate results. If you run into any issues then up subdivisions to 32.
#
# Make the rest of the changes to the cfg based on how many classes you are training your detector on.
#
# **Note:** I set my **max_batches = 10000**, **steps = 8000, 9000**, I changed the **classes = 5** in the three YOLO layers and **filters = 30** in the three convolutional layers before the YOLO layers.
#
# **Optional:** In each of the three yolo layers in the cfg, change one line from random = 1 to **random = 0** to speed up training but slightly reduce accuracy of model. Will also help save memory if you run into any memory issues.

# %%
# upload the custom .cfg back to cloud VM from Google Drive
# !cp /mydrive/yolov3/yolov3_custom.cfg ./cfg

# upload the custom .cfg back to cloud VM from local machine (uncomment to use)
#%cd cfg
#upload()
#%cd ..

# %% [markdown]
# ## ii) obj.names and obj.data
# Create a new file within a code or text editor called **obj.names** and you will make this file exactly the same as your classes.txt in the dataset generation step.
#
# ![image.png](data:image/png;base64,...)
#
# You will also create a **obj.data** file and fill it in like this (change your number of classes accordingly, as well as your backup location)
#
# This backup path is where we will save the weights to of our model throughout training. Create a backup folder in your google drive and put its correct path in this file.
#
# ![image.png](data:image/png;base64,...)

# %%
# upload the obj.names and obj.data files to cloud VM from Google Drive
# !cp /mydrive/yolov3/obj.names ./data
# !cp /mydrive/yolov3/obj.data  ./data

# upload the obj.names and obj.data files to cloud VM from local machine (uncomment to use)
#%cd data
#upload()
#%cd ..

# %% [markdown]
# ## iii) Generating train.txt
# The last configuration file needed before we can begin to train our custom detector is the train.txt file which hold the relative paths to all our training images.
#
# Luckily I have created a script that I showed in a past video that generates train.txt for us.
#
# The script can be accessed from this [Github Repo](https://github.com/theAIGuysCode/YoloGenerateTrainingFile/blob/master/generate_train.py/)
#
# Just download the file to your local machine or Google drive so we can upload it to your cloud VM.

# %%
# upload the generate_train.py script to cloud VM from Google Drive
# !cp /mydrive/yolov3/generate_train.py ./

# upload the generate_train.py script to cloud VM from local machine (uncomment to use)
#upload()

# %%
ls  /mydrive/yolov3/
# Out:
#  backup/             obj.data.gdoc    OIP.jpeg                      yolov3_custom.cfg.gdoc
#  generate_train.py   obj.names       'yolov3_custom (1).cfg.gdoc'   yolov3_custom_last.weights
#  image_test/         obj.names.gdoc   yolov3_custom2.cfg
#  obj.data            obj.zip          yolov3_custom.cfg

# %% [markdown]
# Now we simply run the python script to do all the work for us.

# %%
# !python generate_train.py

# %%
# verify train.txt can be seen in our darknet/data folder
# !ls data/
# Out:
# 9k.tree     eagle.jpg	 imagenet.labels.list	   openimages.names
# coco9k.map  giraffe.jpg  imagenet.shortnames.list  person.jpg
# coco.names  goal.txt	 labels			   scream.jpg
# dog.jpg     horses.jpg	 merge			   voc.names

# %% [markdown]
# If everything went as planned double click on **train.txt** on the left side File Explorer and it should look like this.
# ![image.png](data:image/png;base64,...)
#
# It will contain one line for each training image path.

# %% [markdown]
# # Step 4: Download pre-trained weights for the convolutional layers.
# This step downloads the weights for the convolutional layers of the YOLOv3 network. By using these weights it helps your custom object detector to be way more accurate and not have to train as long. You don't have to use these weights but trust me it will help your modle converge and be accurate way faster. USE IT!

# %%
# upload pretrained convolutional layer weights
# !wget http://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2024-03-18 09:29:55--  http://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 162.0.215.52
# Connecting to pjreddie.com (pjreddie.com)|162.0.215.52|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://pjreddie.com/media/files/darknet53.conv.74 [following]
# --2024-03-18 09:29:55--  https://pjreddie.com/media/files/darknet53.conv.74
# Connecting to pjreddie.com (pjreddie.com)|162.0.215.52|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  17.5MB/s    in 22s
#
# 2024-03-18 09:31:10 (7.05 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %% [markdown]
# # Step 5: Train Your Custom Object Detector!
# The time has finally come! You have made it to the moment of truth! You are now ready to train your custom YOLOv3 object detector on whatever crazy classes you have decided on. So run the following command. (dont_show flag stops a chart from popping up since cloud can't open images on the spot)
# ```
# !./darknet detector train <path to obj.data> <path to custom config> darknet53.conv.74 -dont_show
# ```
# **TIP:** This training could take several hours depending on how many iterations you chose in the .cfg file. You will want to let this run as you sleep or go to work for the day, etc. However, Colab Cloud Service kicks you off it's VMs if you are idle for too long (30-90 mins).
#
# To avoid this hold (CTRL + SHIFT + i) at the same time to open up the inspector view on your browser.
#
# Paste the following code into your console window and hit **Enter**
# ```
# function ClickConnect(){
# console.log("Working");
# document.querySelector("colab-toolbar-button#connect").click()
# }
# setInterval(ClickConnect,60000)
# ```
# Looks like this, it will click the screen every 10 minutes so that you don't get kicked off for being idle! HACKS!
#
# ![image.png](data:image/png;base64,...)

# %%
# train your custom detector
# !./darknet detector train data/obj.data cfg/yolov3_custom.cfg darknet53.conv.74 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#  total_bbox = 7847, rewritten_bbox = 2.497770 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.455065), count: 5, class_loss = 143.730804, iou_loss = 1.246277, total_loss = 144.977081
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 488.218170, iou_loss = 0.000000, total_loss = 488.218170
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1664.865601, iou_loss = 0.000000, total_loss = 1664.865601
#  total_bbox = 7852, rewritten_bbox = 2.496179 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.407769), count: 4, class_loss = 143.541412, iou_loss = 2.678329, total_loss = 146.219742
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 486.719818, iou_loss = 0.000000, total_loss = 486.719818
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1671.760864, iou_loss = 0.000000, total_loss = 1671.760864
#  total_bbox = 7856, rewritten_bbox = 2.494908 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.390013), count: 5, class_loss = 142.889389, iou_loss = 1.306046, total_loss = 144.195435
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 486.227020, iou_loss = 0.000000, total_loss = 486.227020
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1669.497314, iou_loss = 0.000000, total_loss = 1669.497314
#  total_bbox = 7861, rewritten_bbox = 2.493321 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.178934), count: 4, class_loss = 143.395477, iou_loss = 4.379776, total_loss = 147.775253
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 489.664337, iou_loss = 0.000000, total_loss = 489.664337
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1665.803711, iou_loss = 0.000000, total_loss = 1665.803711
#  total_bbox = 7865, rewritten_bbox = 2.492054 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.281621), count: 5, class_loss = 143.600418, iou_loss = 4.202209, total_loss = 147.802628
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.393107), count: 2, class_loss = 487.555023, iou_loss = 1.198181, total_loss = 488.753204
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1668.151489, iou_loss = 0.000000, total_loss = 1668.151489
#  total_bbox = 7872, rewritten_bbox = 2.502541 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.316918), count: 4, class_loss = 143.072311, iou_loss = 2.078598, total_loss = 145.150909
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.524507), count: 1, class_loss = 488.745941, iou_loss = 0.217529, total_loss = 488.963470
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1671.388428, iou_loss = 0.000000, total_loss = 1671.388428
#  total_bbox = 7877, rewritten_bbox = 2.500952 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.308932), count: 4, class_loss = 144.138870, iou_loss = 2.278091, total_loss = 146.416962
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 486.880249, iou_loss = 0.000000, total_loss = 486.880249
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1663.837524, iou_loss = 0.000000, total_loss = 1663.837524
#  total_bbox = 7881, rewritten_bbox = 2.499683 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.469240), count: 6, class_loss = 143.912094, iou_loss = 1.401169, total_loss = 145.313263
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 487.616180, iou_loss = 0.000000, total_loss = 487.616180
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1667.369141, iou_loss = 0.000000, total_loss = 1667.369141
#  total_bbox = 7887, rewritten_bbox = 2.497781 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.437864), count: 3, class_loss = 142.782715, iou_loss = 0.910309, total_loss = 143.693024
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 487.954041, iou_loss = 0.000000, total_loss = 487.954041
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1666.259644, iou_loss = 0.000000, total_loss = 1666.259644
#  total_bbox = 7890, rewritten_bbox = 2.496831 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.314741), count: 2, class_loss = 142.863159, iou_loss = 0.732941, total_loss = 143.596100
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.546835), count: 3, class_loss = 490.389313, iou_loss = 0.956726, total_loss = 491.346039
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1668.110962, iou_loss = 0.000000, total_loss = 1668.110962
#  total_bbox = 7895, rewritten_bbox = 2.495250 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.252408), count: 8, class_loss = 144.697449, iou_loss = 9.454971, total_loss = 154.152420
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 487.423126, iou_loss = 0.000000, total_loss = 487.423126
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1668.324097, iou_loss = 0.000000, total_loss = 1668.324097
#  total_bbox = 7903, rewritten_bbox = 2.492724 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.317624), count: 6, class_loss = 143.745773, iou_loss = 2.919952, total_loss = 146.665726
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 488.673584, iou_loss = 0.000000, total_loss = 488.673584
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1668.819946, iou_loss = 0.000000, total_loss = 1668.819946
#  total_bbox = 7909, rewritten_bbox = 2.490833 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.320975), count: 10, class_loss = 145.319702, iou_loss = 8.513947, total_loss = 153.833649
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.384176), count: 3, class_loss = 489.558167, iou_loss = 2.498566, total_loss = 492.056732
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.444370), count: 1, class_loss = 1668.200439, iou_loss = 0.303467, total_loss = 1668.503906
#  total_bbox = 7923, rewritten_bbox = 2.486432 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.256498), count: 5, class_loss = 144.098755, iou_loss = 5.630936, total_loss = 149.729691
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.314653), count: 2, class_loss = 488.850952, iou_loss = 1.287079, total_loss = 490.138031
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1661.911133, iou_loss = 0.000000, total_loss = 1661.911133
#  total_bbox = 7930, rewritten_bbox = 2.484237 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.232946), count: 3, class_loss = 143.081940, iou_loss = 5.225708, total_loss = 148.307648
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.728760), count: 1, class_loss = 487.802612, iou_loss = 0.180573, total_loss = 487.983185
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1668.611450, iou_loss = 0.000000, total_loss = 1668.611450
#  total_bbox = 7934, rewritten_bbox = 2.482985 %
# 92/6000: loss=767.8 hours left=7.6
#  92: 767.750122, 901.944763 avg loss, 0.000000 rate, 4.324584 seconds, 5888 images, 7.615171 hours left
# Loaded: 0.000115 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.278715), count: 5, class_loss = 142.677734, iou_loss = 4.609436, total_loss = 147.287170
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.231834), count: 1, class_loss = 479.692352, iou_loss = 1.104492, total_loss = 480.796844
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1625.983521, iou_loss = 0.000000, total_loss = 1625.983521
#  total_bbox = 7940, rewritten_bbox = 2.493703 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.429015), count: 6, class_loss = 142.974777, iou_loss = 1.613312, total_loss = 144.588089
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 480.884186, iou_loss = 0.000000, total_loss = 480.884186
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1620.644165, iou_loss = 0.000000, total_loss = 1620.644165
#  total_bbox = 7946, rewritten_bbox = 2.491820 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.485584), count: 4, class_loss = 141.924545, iou_loss = 0.996674, total_loss = 142.921219
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 481.215576, iou_loss = 0.000000, total_loss = 481.215576
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1620.882568, iou_loss = 0.000000, total_loss = 1620.882568
#  total_bbox = 7950, rewritten_bbox = 2.490566 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.390368), count: 4, class_loss = 142.277893, iou_loss = 3.293411, total_loss = 145.571304
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 480.939209, iou_loss = 0.000000, total_loss = 480.939209
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1613.778320, iou_loss = 0.000000, total_loss = 1613.778320
#  total_bbox = 7954, rewritten_bbox = 2.489314 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.502026), count: 4, class_loss = 141.557251, iou_loss = 0.629089, total_loss = 142.186340
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 480.244934, iou_loss = 0.000000, total_loss = 480.244934
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1611.855713, iou_loss = 0.000000, total_loss = 1611.855713
#  total_bbox = 7958, rewritten_bbox = 2.488062 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.442432), count: 4, class_loss = 143.500946, iou_loss = 1.054581, total_loss = 144.555527
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 481.675507, iou_loss = 0.000000, total_loss = 481.675507
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1615.295532, iou_loss = 0.000000, total_loss = 1615.295532
#  total_bbox = 7962, rewritten_bbox = 2.486812 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.250949), count: 3, class_loss = 142.215302, iou_loss = 2.980927, total_loss = 145.196228
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 482.029724, iou_loss = 0.000000, total_loss = 482.029724
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1621.873291, iou_loss = 0.000000, total_loss = 1621.873291
#  total_bbox = 7965, rewritten_bbox = 2.485876 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.279965), count: 3, class_loss = 142.341202, iou_loss = 1.868134, total_loss = 144.209335
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.446192), count: 3, class_loss = 483.320038, iou_loss = 0.860504, total_loss = 484.180542
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1617.716064, iou_loss = 0.000000, total_loss = 1617.716064
#  total_bbox = 7971, rewritten_bbox = 2.484004 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.477116), count: 6, class_loss = 141.975861, iou_loss = 1.647217, total_loss = 143.623077
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 482.612061, iou_loss = 0.000000, total_loss = 482.612061
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1622.480713, iou_loss = 0.000000, total_loss = 1622.480713
#  total_bbox = 7977, rewritten_bbox = 2.482136 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.270497), count: 8, class_loss = 142.776733, iou_loss = 10.292145, total_loss = 153.068878
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.381146), count: 1, class_loss = 480.958466, iou_loss = 0.583618, total_loss = 481.542084
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1622.323730, iou_loss = 0.000000, total_loss = 1622.323730
#  total_bbox = 7986, rewritten_bbox = 2.504383 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.162325), count: 4, class_loss = 142.186707, iou_loss = 4.473190, total_loss = 146.659897
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 479.920044, iou_loss = 0.000000, total_loss = 479.920044
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1615.577637, iou_loss = 0.000000, total_loss = 1615.577637
#  total_bbox = 7990, rewritten_bbox = 2.503129 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.471356), count: 4, class_loss = 140.980072, iou_loss = 0.983749, total_loss = 141.963821
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 481.177429, iou_loss = 0.000000, total_loss = 481.177429
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1616.968872, iou_loss = 0.000000, total_loss = 1616.968872
#  total_bbox = 7994, rewritten_bbox = 2.501876 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.252710), count: 6, class_loss = 142.571030, iou_loss = 5.675507, total_loss = 148.246536
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 481.683228, iou_loss = 0.000000, total_loss = 481.683228
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1622.590454, iou_loss = 0.000000, total_loss = 1622.590454
#  total_bbox = 8000, rewritten_bbox = 2.500000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.397878), count: 5, class_loss = 142.390488, iou_loss = 2.157639, total_loss = 144.548126
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 483.317108, iou_loss = 0.000000, total_loss = 483.317108
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1625.588257, iou_loss = 0.000000, total_loss = 1625.588257
#  total_bbox = 8005, rewritten_bbox = 2.498438 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.136901), count: 4, class_loss = 142.097198, iou_loss = 6.237000, total_loss = 148.334198
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 481.587952, iou_loss = 0.000000, total_loss = 481.587952
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1618.674805, iou_loss = 0.000000, total_loss = 1618.674805
#  total_bbox = 8009, rewritten_bbox = 2.497191 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.374873), count: 5, class_loss = 142.202576, iou_loss = 2.072098, total_loss = 144.274673
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 481.161102, iou_loss = 0.000000, total_loss = 481.161102
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1615.827881, iou_loss = 0.000000, total_loss = 1615.827881
#  total_bbox = 8014, rewritten_bbox = 2.495633 %
# 93/6000: loss=748.8 hours left=7.6
#  93: 748.755493, 886.625854 avg loss, 0.000000 rate, 4.428644 seconds, 5952 images, 7.609993 hours left
# Loaded: 0.000127 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.291999), count: 4, class_loss = 141.199005, iou_loss = 2.846771, total_loss = 144.045776
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 475.742310, iou_loss = 0.000000, total_loss = 475.742310
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1569.635498, iou_loss = 0.000000, total_loss = 1569.635498
#  total_bbox = 8018, rewritten_bbox = 2.494388 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.394296), count: 6, class_loss = 143.316620, iou_loss = 3.680298, total_loss = 146.996918
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.456505), count: 2, class_loss = 474.634491, iou_loss = 1.172394, total_loss = 475.806885
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1569.684814, iou_loss = 0.000000, total_loss = 1569.684814
#  total_bbox = 8026, rewritten_bbox = 2.491901 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.409186), count: 4, class_loss = 140.598129, iou_loss = 1.474945, total_loss = 142.073074
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 472.389771, iou_loss = 0.000000, total_loss = 472.389771
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1560.654785, iou_loss = 0.000000, total_loss = 1560.654785
#  total_bbox = 8030, rewritten_bbox = 2.490660 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.383293), count: 6, class_loss = 141.598557, iou_loss = 4.672958, total_loss = 146.271515
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.179108), count: 1, class_loss = 473.142059, iou_loss = 1.066376, total_loss = 474.208435
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1569.264648, iou_loss = 0.000000, total_loss = 1569.264648
#  total_bbox = 8037, rewritten_bbox = 2.488491 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.405682), count: 5, class_loss = 141.468796, iou_loss = 1.546158, total_loss = 143.014954
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.540475), count: 1, class_loss = 473.340332, iou_loss = 0.124237, total_loss = 473.464569
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1563.332642, iou_loss = 0.000000, total_loss = 1563.332642
#  total_bbox = 8043, rewritten_bbox = 2.486634 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.321172), count: 2, class_loss = 141.173645, iou_loss = 0.962097, total_loss = 142.135742
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.189588), count: 2, class_loss = 475.533081, iou_loss = 2.752747, total_loss = 478.285828
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1576.370239, iou_loss = 0.000000, total_loss = 1576.370239
#  total_bbox = 8047, rewritten_bbox = 2.485398 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.429322), count: 4, class_loss = 141.037094, iou_loss = 1.544708, total_loss = 142.581802
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.321618), count: 6, class_loss = 476.343384, iou_loss = 3.750183, total_loss = 480.093567
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1563.212524, iou_loss = 0.000000, total_loss = 1563.212524
#  total_bbox = 8057, rewritten_bbox = 2.482314 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.314197), count: 4, class_loss = 141.663101, iou_loss = 2.388901, total_loss = 144.052002
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.132372), count: 1, class_loss = 473.833527, iou_loss = 1.244110, total_loss = 475.077637
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1566.105225, iou_loss = 0.000000, total_loss = 1566.105225
#  total_bbox = 8062, rewritten_bbox = 2.480774 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.238174), count: 4, class_loss = 141.339005, iou_loss = 2.737885, total_loss = 144.076889
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 475.301666, iou_loss = 0.000000, total_loss = 475.301666
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1565.282593, iou_loss = 0.000000, total_loss = 1565.282593
#  total_bbox = 8066, rewritten_bbox = 2.479544 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.214111), count: 3, class_loss = 140.987106, iou_loss = 3.123734, total_loss = 144.110840
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.193696), count: 1, class_loss = 474.238647, iou_loss = 1.381775, total_loss = 475.620422
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1575.139771, iou_loss = 0.000000, total_loss = 1575.139771
#  total_bbox = 8070, rewritten_bbox = 2.478315 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.371736), count: 4, class_loss = 141.450409, iou_loss = 2.477646, total_loss = 143.928055
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 472.307709, iou_loss = 0.000000, total_loss = 472.307709
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.267710), count: 1, class_loss = 1568.491943, iou_loss = 0.788086, total_loss = 1569.280029
#  total_bbox = 8075, rewritten_bbox = 2.476780 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.200711), count: 3, class_loss = 140.950241, iou_loss = 2.206772, total_loss = 143.157013
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.391750), count: 2, class_loss = 475.893829, iou_loss = 1.005981, total_loss = 476.899811
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1579.075806, iou_loss = 0.000000, total_loss = 1579.075806
#  total_bbox = 8080, rewritten_bbox = 2.475248 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.317840), count: 4, class_loss = 142.026779, iou_loss = 3.711487, total_loss = 145.738266
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.246650), count: 1, class_loss = 474.981049, iou_loss = 1.003418, total_loss = 475.984467
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1567.243042, iou_loss = 0.000000, total_loss = 1567.243042
#  total_bbox = 8085, rewritten_bbox = 2.473717 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.313421), count: 4, class_loss = 141.390839, iou_loss = 3.244339, total_loss = 144.635178
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 473.851196, iou_loss = 0.000000, total_loss = 473.851196
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1565.677124, iou_loss = 0.000000, total_loss = 1565.677124
#  total_bbox = 8089, rewritten_bbox = 2.472493 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.163380), count: 4, class_loss = 141.753525, iou_loss = 3.536026, total_loss = 145.289551
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 473.628448, iou_loss = 0.000000, total_loss = 473.628448
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1565.293457, iou_loss = 0.000000, total_loss = 1565.293457
#  total_bbox = 8093, rewritten_bbox = 2.471272 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.302453), count: 4, class_loss = 141.764313, iou_loss = 3.520157, total_loss = 145.284470
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.156396), count: 1, class_loss = 474.593201, iou_loss = 0.980377, total_loss = 475.573578
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1563.993286, iou_loss = 0.000000, total_loss = 1563.993286
#  total_bbox = 8098, rewritten_bbox = 2.469746 %
# 94/6000: loss=729.2 hours left=7.6
#  94: 729.184875, 870.881775 avg loss, 0.000000 rate, 4.330538 seconds, 6016 images, 7.606562 hours left
# Loaded: 0.000109 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.347981), count: 3, class_loss = 140.069443, iou_loss = 1.408112, total_loss = 141.477554
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.281167), count: 2, class_loss = 468.042358, iou_loss = 1.576233, total_loss = 469.618591
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1518.830811, iou_loss = 0.000000, total_loss = 1518.830811
#  total_bbox = 8103, rewritten_bbox = 2.468222 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.293646), count: 6, class_loss = 141.377869, iou_loss = 3.960678, total_loss = 145.338547
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 466.337402, iou_loss = 0.000000, total_loss = 466.337402
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1517.062134, iou_loss = 0.000000, total_loss = 1517.062134
#  total_bbox = 8109, rewritten_bbox = 2.466395 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.355882), count: 5, class_loss = 140.144302, iou_loss = 5.014786, total_loss = 145.159088
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.255495), count: 1, class_loss = 468.879486, iou_loss = 1.012512, total_loss = 469.891998
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1521.099731, iou_loss = 0.000000, total_loss = 1521.099731
#  total_bbox = 8115, rewritten_bbox = 2.476895 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.255398), count: 5, class_loss = 139.543045, iou_loss = 3.270706, total_loss = 142.813751
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 467.540894, iou_loss = 0.000000, total_loss = 467.540894
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1514.823608, iou_loss = 0.000000, total_loss = 1514.823608
#  total_bbox = 8120, rewritten_bbox = 2.475369 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.155248), count: 3, class_loss = 140.442108, iou_loss = 2.582047, total_loss = 143.024155
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.487023), count: 1, class_loss = 465.429962, iou_loss = 0.338715, total_loss = 465.768677
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1517.403564, iou_loss = 0.000000, total_loss = 1517.403564
#  total_bbox = 8124, rewritten_bbox = 2.474151 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.335218), count: 6, class_loss = 140.845078, iou_loss = 3.453812, total_loss = 144.298889
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.324304), count: 1, class_loss = 464.195740, iou_loss = 0.644012, total_loss = 464.839752
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1516.092041, iou_loss = 0.000000, total_loss = 1516.092041
#  total_bbox = 8131, rewritten_bbox = 2.472021 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.427129), count: 2, class_loss = 139.676361, iou_loss = 0.732498, total_loss = 140.408859
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.254422), count: 1, class_loss = 467.680878, iou_loss = 0.942169, total_loss = 468.623047
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1514.350586, iou_loss = 0.000000, total_loss = 1514.350586
#  total_bbox = 8134, rewritten_bbox = 2.471109 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.347040), count: 5, class_loss = 140.959579, iou_loss = 2.107071, total_loss = 143.066650
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.409514), count: 4, class_loss = 467.019257, iou_loss = 4.813202, total_loss = 471.832458
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1517.195312, iou_loss = 0.000000, total_loss = 1517.195312
#  total_bbox = 8143, rewritten_bbox = 2.468378 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.256177), count: 4, class_loss = 140.386459, iou_loss = 1.967102, total_loss = 142.353561
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 465.521149, iou_loss = 0.000000, total_loss = 465.521149
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1513.798340, iou_loss = 0.000000, total_loss = 1513.798340
#  total_bbox = 8147, rewritten_bbox = 2.467166 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.498029), count: 3, class_loss = 138.840149, iou_loss = 1.687180, total_loss = 140.527328
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.180555), count: 3, class_loss = 466.485199, iou_loss = 9.390076, total_loss = 475.875275
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1518.723145, iou_loss = 0.000000, total_loss = 1518.723145
#  total_bbox = 8153, rewritten_bbox = 2.477616 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.297871), count: 4, class_loss = 140.160965, iou_loss = 1.651474, total_loss = 141.812439
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 466.323578, iou_loss = 0.000000, total_loss = 466.323578
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1515.829468, iou_loss = 0.000000, total_loss = 1515.829468
#  total_bbox = 8157, rewritten_bbox = 2.476401 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.168320), count: 5, class_loss = 140.350052, iou_loss = 4.996780, total_loss = 145.346832
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 467.627014, iou_loss = 0.000000, total_loss = 467.627014
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1520.161377, iou_loss = 0.000000, total_loss = 1520.161377
#  total_bbox = 8162, rewritten_bbox = 2.474884 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.254790), count: 6, class_loss = 139.845139, iou_loss = 7.029419, total_loss = 146.874557
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 464.558502, iou_loss = 0.000000, total_loss = 464.558502
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1515.530029, iou_loss = 0.000000, total_loss = 1515.530029
#  total_bbox = 8168, rewritten_bbox = 2.473066 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.303533), count: 6, class_loss = 140.731735, iou_loss = 5.333084, total_loss = 146.064819
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 464.986084, iou_loss = 0.000000, total_loss = 464.986084
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1510.867676, iou_loss = 0.000000, total_loss = 1510.867676
#  total_bbox = 8174, rewritten_bbox = 2.471250 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.358627), count: 6, class_loss = 140.261307, iou_loss = 3.056641, total_loss = 143.317947
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 469.144775, iou_loss = 0.000000, total_loss = 469.144775
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1512.576294, iou_loss = 0.000000, total_loss = 1512.576294
#  total_bbox = 8180, rewritten_bbox = 2.469438 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.369810), count: 6, class_loss = 141.040558, iou_loss = 2.949371, total_loss = 143.989929
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.210856), count: 1, class_loss = 466.123901, iou_loss = 1.325928, total_loss = 467.449829
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1513.082764, iou_loss = 0.000000, total_loss = 1513.082764
#  total_bbox = 8187, rewritten_bbox = 2.467326 %
# 95/6000: loss=709.2 hours left=7.6
#  95: 709.150818, 854.708679 avg loss, 0.000000 rate, 4.331909 seconds, 6080 images, 7.601543 hours left
# Loaded: 0.000111 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.417822), count: 5, class_loss = 139.822845, iou_loss = 2.073868, total_loss = 141.896713
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 459.635925, iou_loss = 0.000000, total_loss = 459.635925
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1457.970459, iou_loss = 0.000000, total_loss = 1457.970459
#  total_bbox = 8192, rewritten_bbox = 2.465820 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.227912), count: 3, class_loss = 139.116364, iou_loss = 1.578186, total_loss = 140.694550
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.210948), count: 1, class_loss = 459.936371, iou_loss = 1.224762, total_loss = 461.161133
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1468.102539, iou_loss = 0.000000, total_loss = 1468.102539
#  total_bbox = 8196, rewritten_bbox = 2.464617 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.369867), count: 4, class_loss = 139.084183, iou_loss = 1.917313, total_loss = 141.001495
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 459.023651, iou_loss = 0.000000, total_loss = 459.023651
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1455.564087, iou_loss = 0.000000, total_loss = 1455.564087
#  total_bbox = 8200, rewritten_bbox = 2.463415 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.234091), count: 4, class_loss = 140.126801, iou_loss = 2.578781, total_loss = 142.705582
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 459.200104, iou_loss = 0.000000, total_loss = 459.200104
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1465.902710, iou_loss = 0.000000, total_loss = 1465.902710
#  total_bbox = 8204, rewritten_bbox = 2.462214 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.397059), count: 2, class_loss = 138.448135, iou_loss = 0.988403, total_loss = 139.436539
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.497679), count: 2, class_loss = 459.281464, iou_loss = 0.544861, total_loss = 459.826324
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1459.775757, iou_loss = 0.000000, total_loss = 1459.775757
#  total_bbox = 8208, rewritten_bbox = 2.461014 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.202036), count: 5, class_loss = 139.265411, iou_loss = 4.123047, total_loss = 143.388458
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 458.281525, iou_loss = 0.000000, total_loss = 458.281525
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1463.005005, iou_loss = 0.000000, total_loss = 1463.005005
#  total_bbox = 8213, rewritten_bbox = 2.459515 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.479738), count: 4, class_loss = 138.177444, iou_loss = 1.092560, total_loss = 139.270004
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 460.571259, iou_loss = 0.000000, total_loss = 460.571259
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1459.512573, iou_loss = 0.000000, total_loss = 1459.512573
#  total_bbox = 8217, rewritten_bbox = 2.458318 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.248773), count: 4, class_loss = 138.775330, iou_loss = 4.215790, total_loss = 142.991119
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 457.244659, iou_loss = 0.000000, total_loss = 457.244659
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1463.064209, iou_loss = 0.000000, total_loss = 1463.064209
#  total_bbox = 8221, rewritten_bbox = 2.457122 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.301618), count: 4, class_loss = 138.836365, iou_loss = 4.011063, total_loss = 142.847427
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 458.071594, iou_loss = 0.000000, total_loss = 458.071594
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1464.604858, iou_loss = 0.000000, total_loss = 1464.604858
#  total_bbox = 8225, rewritten_bbox = 2.455927 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.229279), count: 4, class_loss = 138.966034, iou_loss = 2.833313, total_loss = 141.799347
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 460.022522, iou_loss = 0.000000, total_loss = 460.022522
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.519715), count: 2, class_loss = 1467.716431, iou_loss = 0.939575, total_loss = 1468.656006
#  total_bbox = 8231, rewritten_bbox = 2.454137 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.303451), count: 5, class_loss = 139.445251, iou_loss = 3.956039, total_loss = 143.401291
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 460.293274, iou_loss = 0.000000, total_loss = 460.293274
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1465.934570, iou_loss = 0.000000, total_loss = 1465.934570
#  total_bbox = 8236, rewritten_bbox = 2.452647 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.278461), count: 4, class_loss = 138.254303, iou_loss = 3.840607, total_loss = 142.094910
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 459.559784, iou_loss = 0.000000, total_loss = 459.559784
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1461.052246, iou_loss = 0.000000, total_loss = 1461.052246
#  total_bbox = 8240, rewritten_bbox = 2.451456 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.368338), count: 5, class_loss = 139.027481, iou_loss = 1.994186, total_loss = 141.021667
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 457.368408, iou_loss = 0.000000, total_loss = 457.368408
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1466.276978, iou_loss = 0.000000, total_loss = 1466.276978
#  total_bbox = 8245, rewritten_bbox = 2.449970 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.318324), count: 3, class_loss = 139.166931, iou_loss = 1.226105, total_loss = 140.393036
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.075249), count: 2, class_loss = 459.865692, iou_loss = 6.687988, total_loss = 466.553680
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1461.230957, iou_loss = 0.000000, total_loss = 1461.230957
#  total_bbox = 8250, rewritten_bbox = 2.448485 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.264304), count: 5, class_loss = 139.580093, iou_loss = 3.771713, total_loss = 143.351807
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 460.641754, iou_loss = 0.000000, total_loss = 460.641754
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1468.198486, iou_loss = 0.000000, total_loss = 1468.198486
#  total_bbox = 8255, rewritten_bbox = 2.447002 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.317409), count: 3, class_loss = 137.953827, iou_loss = 2.305008, total_loss = 140.258835
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.443375), count: 2, class_loss = 458.568268, iou_loss = 2.076843, total_loss = 460.645111
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1460.297852, iou_loss = 0.000000, total_loss = 1460.297852
#  total_bbox = 8260, rewritten_bbox = 2.445521 %
# 96/6000: loss=688.2 hours left=7.6
#  96: 688.204224, 838.058228 avg loss, 0.000000 rate, 4.447307 seconds, 6144 images, 7.596586 hours left
# Loaded: 0.000096 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.461100), count: 6, class_loss = 137.941040, iou_loss = 1.702164, total_loss = 139.643204
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 452.285858, iou_loss = 0.000000, total_loss = 452.285858
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1414.902710, iou_loss = 0.000000, total_loss = 1414.902710
#  total_bbox = 8266, rewritten_bbox = 2.443745 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.357201), count: 3, class_loss = 137.221146, iou_loss = 1.106323, total_loss = 138.327469
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 450.386902, iou_loss = 0.000000, total_loss = 450.386902
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1420.499146, iou_loss = 0.000000, total_loss = 1420.499146
#  total_bbox = 8269, rewritten_bbox = 2.442859 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.545893), count: 2, class_loss = 137.146820, iou_loss = 0.429245, total_loss = 137.576065
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.266197), count: 5, class_loss = 452.996643, iou_loss = 12.040924, total_loss = 465.037567
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 1419.842773, iou_loss = 0.000000, total_loss = 1419.842773
#  total_bbox = 8276, rewritten_bbox = 2.464959 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.377313), count: 4, class_loss = 137.677582, iou_loss = 2.236588, total_loss = 139.914169
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 450.349335, iou_loss = 0.000000, total_loss = 450.349335
# ...
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.509996), count: 2, class_loss = 18.333000, iou_loss = 0.676298, total_loss = 19.009298
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 13.263716, iou_loss = 0.000000, total_loss = 13.263716
#  total_bbox = 14049, rewritten_bbox = 2.363158 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.339793), count: 7, class_loss = 20.178181, iou_loss = 4.164185, total_loss = 24.342365
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 16.937830, iou_loss = 0.000000, total_loss = 16.937830
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 13.115335, iou_loss = 0.000000, total_loss = 13.115335
#  total_bbox = 14056, rewritten_bbox = 2.361981 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.311049), count: 4, class_loss = 18.926979, iou_loss = 2.411507, total_loss = 21.338486
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 16.637503, iou_loss = 0.000000, total_loss = 16.637503
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 13.173858, iou_loss = 0.000000, total_loss = 13.173858
#  total_bbox = 14060, rewritten_bbox = 2.361309 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.251258), count: 4, class_loss = 19.046991, iou_loss = 3.005075, total_loss = 22.052067
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 17.366291, iou_loss = 0.000000, total_loss = 17.366291
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 13.166060, iou_loss = 0.000000, total_loss = 13.166060
#  total_bbox = 14064, rewritten_bbox = 2.360637 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.255594), count: 4, class_loss = 18.401314, iou_loss = 3.415827, total_loss = 21.817141
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 16.505766, iou_loss = 0.000000, total_loss = 16.505766
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 12.756429, iou_loss = 0.000000, total_loss = 12.756429
#  total_bbox = 14068, rewritten_bbox = 2.359966 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.542501), count: 5, class_loss = 19.244879, iou_loss = 1.381714, total_loss = 20.626593
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 17.010283, iou_loss = 0.000000, total_loss = 17.010283
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 13.336788, iou_loss = 0.000000, total_loss = 13.336788
#  total_bbox = 14073, rewritten_bbox = 2.359128 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.448471), count: 4, class_loss = 18.818523, iou_loss = 1.058788, total_loss = 19.877312
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 16.958879, iou_loss = 0.000000, total_loss = 16.958879
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 13.141650, iou_loss = 0.000000, total_loss = 13.141650
#  total_bbox = 14077, rewritten_bbox = 2.358457 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.487212), count: 4, class_loss = 18.720640, iou_loss = 1.678558, total_loss = 20.399199
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 16.850340, iou_loss = 0.000000, total_loss = 16.850340
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 13.144411, iou_loss = 0.000000, total_loss = 13.144411
#  total_bbox = 14081, rewritten_bbox = 2.357787 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.450896), count: 6, class_loss = 19.348309, iou_loss = 2.294411, total_loss = 21.642719
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 17.221354, iou_loss = 0.000000, total_loss = 17.221354
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 13.625023, iou_loss = 0.000000, total_loss = 13.625023
#  total_bbox = 14087, rewritten_bbox = 2.356783 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.324787), count: 4, class_loss = 18.596258, iou_loss = 1.609512, total_loss = 20.205770
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 16.529943, iou_loss = 0.000000, total_loss = 16.529943
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 12.656489, iou_loss = 0.000000, total_loss = 12.656489
#  total_bbox = 14091, rewritten_bbox = 2.356114 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.400318), count: 4, class_loss = 18.982044, iou_loss = 1.702787, total_loss = 20.684832
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 17.886326, iou_loss = 0.000000, total_loss = 17.886326
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 13.572629, iou_loss = 0.000000, total_loss = 13.572629
#  total_bbox = 14095, rewritten_bbox = 2.355445 %
# 165/6000: loss=17.5 hours left=7.3
#  165: 17.519051, 37.116081 avg loss, 0.000001 rate, 4.329234 seconds, 10560 images, 7.329846 hours left
# Loaded: 0.000133 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.250261), count: 3, class_loss = 17.596502, iou_loss = 2.531446, total_loss = 20.127949
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.305612), count: 1, class_loss = 15.836926, iou_loss = 0.838810, total_loss = 16.675735
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.597090), count: 1, class_loss = 12.877236, iou_loss = 0.105740, total_loss = 12.982976
#  total_bbox = 14100, rewritten_bbox = 2.354610 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.561382), count: 3, class_loss = 17.845394, iou_loss = 0.296286, total_loss = 18.141680
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.599730), count: 1, class_loss = 16.388615, iou_loss = 0.150066, total_loss = 16.538681
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 12.779515, iou_loss = 0.000000, total_loss = 12.779515
#  total_bbox = 14104, rewritten_bbox = 2.353942 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.340738), count: 4, class_loss = 17.705820, iou_loss = 2.187273, total_loss = 19.893093
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 15.623582, iou_loss = 0.000000, total_loss = 15.623582
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 12.104425, iou_loss = 0.000000, total_loss = 12.104425
#  total_bbox = 14108, rewritten_bbox = 2.353275 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.188621), count: 6, class_loss = 19.143496, iou_loss = 4.935795, total_loss = 24.079290
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 16.040403, iou_loss = 0.000000, total_loss = 16.040403
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 12.669559, iou_loss = 0.000000, total_loss = 12.669559
#  total_bbox = 14114, rewritten_bbox = 2.352274 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.336402), count: 7, class_loss = 19.059523, iou_loss = 3.233273, total_loss = 22.292795
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.164878), count: 1, class_loss = 16.176352, iou_loss = 1.251831, total_loss = 17.428183
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.071867), count: 1, class_loss = 12.647211, iou_loss = 4.463764, total_loss = 17.110975
#  total_bbox = 14123, rewritten_bbox = 2.350775 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.319089), count: 17, class_loss = 22.586298, iou_loss = 13.638346, total_loss = 36.224644
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.294662), count: 4, class_loss = 17.275179, iou_loss = 4.571407, total_loss = 21.846586
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.216105), count: 2, class_loss = 13.460711, iou_loss = 3.466482, total_loss = 16.927193
#  total_bbox = 14146, rewritten_bbox = 2.346953 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.305843), count: 6, class_loss = 18.835524, iou_loss = 3.156542, total_loss = 21.992065
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 15.803063, iou_loss = 0.000000, total_loss = 15.803063
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 12.328612, iou_loss = 0.000000, total_loss = 12.328612
#  total_bbox = 14152, rewritten_bbox = 2.345958 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.290553), count: 3, class_loss = 17.502293, iou_loss = 1.202806, total_loss = 18.705099
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.521272), count: 1, class_loss = 16.162968, iou_loss = 0.252413, total_loss = 16.415380
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 12.571680, iou_loss = 0.000000, total_loss = 12.571680
#  total_bbox = 14156, rewritten_bbox = 2.345295 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.151258), count: 4, class_loss = 17.725048, iou_loss = 12.914173, total_loss = 30.639221
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.409848), count: 1, class_loss = 15.728495, iou_loss = 0.404196, total_loss = 16.132690
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.362530), count: 1, class_loss = 12.612807, iou_loss = 0.563652, total_loss = 13.176459
#  total_bbox = 14162, rewritten_bbox = 2.351363 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.531670), count: 6, class_loss = 18.872473, iou_loss = 1.853237, total_loss = 20.725710
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 16.132160, iou_loss = 0.000000, total_loss = 16.132160
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 12.918808, iou_loss = 0.000000, total_loss = 12.918808
#  total_bbox = 14168, rewritten_bbox = 2.350367 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.398069), count: 5, class_loss = 18.614567, iou_loss = 3.247940, total_loss = 21.862507
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 16.755135, iou_loss = 0.000000, total_loss = 16.755135
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 13.679118, iou_loss = 0.000000, total_loss = 13.679118
#  total_bbox = 14173, rewritten_bbox = 2.349538 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.318887), count: 4, class_loss = 17.585423, iou_loss = 3.687246, total_loss = 21.272669
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.152819), count: 1, class_loss = 15.639942, iou_loss = 1.347006, total_loss = 16.986948
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 12.308343, iou_loss = 0.000000, total_loss = 12.308343
#  total_bbox = 14178, rewritten_bbox = 2.348709 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.449600), count: 4, class_loss = 17.957043, iou_loss = 2.732122, total_loss = 20.689165
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.471721), count: 5, class_loss = 17.988676, iou_loss = 2.352768, total_loss = 20.341444
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.265987), count: 1, class_loss = 12.685985, iou_loss = 0.632821, total_loss = 13.318806
#  total_bbox = 14188, rewritten_bbox = 2.347054 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.327926), count: 7, class_loss = 18.691401, iou_loss = 5.248407, total_loss = 23.939808
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 16.057608, iou_loss = 0.000000, total_loss = 16.057608
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 12.721534, iou_loss = 0.000000, total_loss = 12.721534
#  total_bbox = 14195, rewritten_bbox = 2.345896 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.170990), count: 4, class_loss = 18.213110, iou_loss = 4.953426, total_loss = 23.166536
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.129927), count: 1, class_loss = 16.795891, iou_loss = 1.060520, total_loss = 17.856411
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 12.832250, iou_loss = 0.000000, total_loss = 12.832250
#  total_bbox = 14200, rewritten_bbox = 2.345070 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.415988), count: 6, class_loss = 19.141981, iou_loss = 4.344196, total_loss = 23.486177
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 16.143789, iou_loss = 0.000000, total_loss = 16.143789
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 12.521840, iou_loss = 0.000000, total_loss = 12.521840
#  total_bbox = 14206, rewritten_bbox = 2.344080 %
# 166/6000: loss=17.8 hours left=7.3
#  166: 17.770172, 35.181492 avg loss, 0.000001 rate, 4.343410 seconds, 10624 images, 7.326719 hours left
# Loaded: 0.000098 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.384570), count: 6, class_loss = 17.623320, iou_loss = 3.306454, total_loss = 20.929773
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.085178), count: 1, class_loss = 15.399219, iou_loss = 2.773280, total_loss = 18.172499
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 11.230649, iou_loss = 0.000000, total_loss = 11.230649
#  total_bbox = 14213, rewritten_bbox = 2.342926 %
# ^C

# %% [markdown]
# You can observe a chart of how your model did throughout the training process by running the below command. It shows a chart of your average loss vs. iterations. For your model to be 'accurate' you would aim for a loss under 2.

# %%
imShow('chart.png')

# %% [markdown]
# **TRICK**: If for some reason you get an error or your Colab goes idle during training, you have not lost your weights! Every 100 iterations a weights file called **yolov3_custom_last.weights** is saved to **mydrive/yolov3/backup/** folder (wherever your backup folder is). This is why we created this folder in our Google drive and not on the cloud VM. If your runtime crashes and your backup folder was in your cloud VM you would lose your weights and your training progress.
#
# We can kick off training from our last saved weights file so that we don't have to restart! WOOHOO! Just run the following command but with your backup location.
# ```
# !./darknet detector train data/obj.data cfg/yolov3_custom.cfg /mydrive/yolov3/backup/yolov3_custom_last.weights -dont_show
# ```

# %%
# !./darknet detector train data/obj.data cfg/yolov3_custom.cfg /mydrive/yolov3/backup/yolov3_custom_last.weights -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70279, rewritten_bbox = 2.463040 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.683130), count: 5, class_loss = 0.802315, iou_loss = 0.568768, total_loss = 1.371083
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000817, iou_loss = 0.000000, total_loss = 0.000817
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70284, rewritten_bbox = 2.462865 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.694052), count: 4, class_loss = 0.774679, iou_loss = 0.450265, total_loss = 1.224944
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.563956), count: 1, class_loss = 0.351504, iou_loss = 0.200103, total_loss = 0.551607
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000002, iou_loss = 0.000000, total_loss = 0.000002
#  total_bbox = 70289, rewritten_bbox = 2.462690 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.576108), count: 8, class_loss = 1.244421, iou_loss = 1.144678, total_loss = 2.389100
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000239, iou_loss = 0.000000, total_loss = 0.000239
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70297, rewritten_bbox = 2.462409 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.745026), count: 3, class_loss = 0.504213, iou_loss = 0.253153, total_loss = 0.757366
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.628774), count: 1, class_loss = 0.439527, iou_loss = 0.212310, total_loss = 0.651837
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000002, iou_loss = 0.000000, total_loss = 0.000002
#  total_bbox = 70301, rewritten_bbox = 2.462269 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.618641), count: 4, class_loss = 1.149206, iou_loss = 0.484766, total_loss = 1.633972
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000147, iou_loss = 0.000000, total_loss = 0.000147
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000002, iou_loss = 0.000000, total_loss = 0.000002
#  total_bbox = 70305, rewritten_bbox = 2.462129 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.748703), count: 5, class_loss = 0.916024, iou_loss = 0.357248, total_loss = 1.273273
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.003158, iou_loss = 0.000000, total_loss = 0.003158
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70310, rewritten_bbox = 2.461954 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.673322), count: 4, class_loss = 0.928035, iou_loss = 0.317137, total_loss = 1.245172
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.560863), count: 2, class_loss = 0.479031, iou_loss = 0.340359, total_loss = 0.819390
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000002, iou_loss = 0.000000, total_loss = 0.000002
#  total_bbox = 70316, rewritten_bbox = 2.461744 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.667308), count: 7, class_loss = 1.492673, iou_loss = 0.888362, total_loss = 2.381035
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000334, iou_loss = 0.000000, total_loss = 0.000334
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70323, rewritten_bbox = 2.462921 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.609616), count: 7, class_loss = 1.055521, iou_loss = 0.964864, total_loss = 2.020385
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.007316, iou_loss = 0.000000, total_loss = 0.007316
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70330, rewritten_bbox = 2.462676 %
# 926/1000: loss=1.0 hours left=0.2
#  926: 1.012496, 0.664670 avg loss, 0.000735 rate, 4.425520 seconds, 59264 images, 0.209474 hours left
# Loaded: 0.000091 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.549048), count: 4, class_loss = 0.816911, iou_loss = 0.426903, total_loss = 1.243813
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000797, iou_loss = 0.000000, total_loss = 0.000797
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70334, rewritten_bbox = 2.462536 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.672144), count: 4, class_loss = 0.818017, iou_loss = 0.300408, total_loss = 1.118425
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.033361, iou_loss = 0.000000, total_loss = 0.033361
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70338, rewritten_bbox = 2.462396 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.649056), count: 6, class_loss = 0.884412, iou_loss = 0.599356, total_loss = 1.483768
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.014202, iou_loss = 0.000000, total_loss = 0.014202
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70344, rewritten_bbox = 2.465029 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.666246), count: 6, class_loss = 1.808481, iou_loss = 0.758847, total_loss = 2.567328
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.002010, iou_loss = 0.000000, total_loss = 0.002010
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000002, iou_loss = 0.000000, total_loss = 0.000002
#  total_bbox = 70350, rewritten_bbox = 2.464819 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.602348), count: 5, class_loss = 0.697731, iou_loss = 0.768379, total_loss = 1.466110
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.627643), count: 1, class_loss = 0.360286, iou_loss = 0.160089, total_loss = 0.520374
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000002, iou_loss = 0.000000, total_loss = 0.000002
#  total_bbox = 70356, rewritten_bbox = 2.464609 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.505830), count: 2, class_loss = 0.634383, iou_loss = 0.563039, total_loss = 1.197422
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.696621), count: 1, class_loss = 0.342837, iou_loss = 0.073948, total_loss = 0.416785
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000003, iou_loss = 0.000000, total_loss = 0.000003
#  total_bbox = 70359, rewritten_bbox = 2.464504 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.662750), count: 7, class_loss = 1.115672, iou_loss = 0.790962, total_loss = 1.906634
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.298726), count: 1, class_loss = 0.419847, iou_loss = 0.710545, total_loss = 1.130392
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70367, rewritten_bbox = 2.464223 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.549904), count: 11, class_loss = 1.560060, iou_loss = 2.738429, total_loss = 4.298490
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.001106, iou_loss = 0.000000, total_loss = 0.001106
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000002, iou_loss = 0.000000, total_loss = 0.000002
#  total_bbox = 70378, rewritten_bbox = 2.465259 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.581703), count: 5, class_loss = 0.986524, iou_loss = 0.849886, total_loss = 1.836410
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000034, iou_loss = 0.000000, total_loss = 0.000034
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70383, rewritten_bbox = 2.465084 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.694631), count: 4, class_loss = 0.559507, iou_loss = 0.370526, total_loss = 0.930033
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.428998), count: 1, class_loss = 0.465265, iou_loss = 0.497217, total_loss = 0.962482
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70388, rewritten_bbox = 2.464909 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.641130), count: 4, class_loss = 0.735335, iou_loss = 0.407219, total_loss = 1.142554
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000098, iou_loss = 0.000000, total_loss = 0.000098
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70392, rewritten_bbox = 2.464769 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.638601), count: 4, class_loss = 0.678123, iou_loss = 0.548178, total_loss = 1.226300
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.528466), count: 1, class_loss = 0.284020, iou_loss = 0.266353, total_loss = 0.550373
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70397, rewritten_bbox = 2.464594 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.663142), count: 3, class_loss = 0.524364, iou_loss = 0.300893, total_loss = 0.825257
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.370633), count: 1, class_loss = 0.412970, iou_loss = 0.441259, total_loss = 0.854229
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000002, iou_loss = 0.000000, total_loss = 0.000002
#  total_bbox = 70401, rewritten_bbox = 2.464454 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.733537), count: 6, class_loss = 0.895680, iou_loss = 0.353046, total_loss = 1.248726
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.007494, iou_loss = 0.000000, total_loss = 0.007494
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000002, iou_loss = 0.000000, total_loss = 0.000002
#  total_bbox = 70407, rewritten_bbox = 2.464244 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.585891), count: 4, class_loss = 1.078963, iou_loss = 0.645040, total_loss = 1.724002
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.002250, iou_loss = 0.000000, total_loss = 0.002250
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70411, rewritten_bbox = 2.464104 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.601006), count: 9, class_loss = 1.213147, iou_loss = 1.056840, total_loss = 2.269987
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.004253, iou_loss = 0.000000, total_loss = 0.004253
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.322980), count: 1, class_loss = 0.392019, iou_loss = 0.356419, total_loss = 0.748438
#  total_bbox = 70421, rewritten_bbox = 2.463754 %
# 927/1000: loss=0.7 hours left=0.2
#  927: 0.661124, 0.664315 avg loss, 0.000738 rate, 4.299464 seconds, 59328 images, 0.208289 hours left
# Loaded: 0.000084 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.630654), count: 5, class_loss = 0.944794, iou_loss = 0.435233, total_loss = 1.380027
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.677418), count: 1, class_loss = 0.214354, iou_loss = 0.044568, total_loss = 0.258921
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70427, rewritten_bbox = 2.463544 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.674180), count: 3, class_loss = 0.558067, iou_loss = 0.428436, total_loss = 0.986503
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.336331), count: 2, class_loss = 0.545354, iou_loss = 1.271509, total_loss = 1.816863
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70432, rewritten_bbox = 2.463369 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.515163), count: 3, class_loss = 0.477614, iou_loss = 0.433017, total_loss = 0.910631
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.304489), count: 1, class_loss = 0.193814, iou_loss = 0.698561, total_loss = 0.892376
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70436, rewritten_bbox = 2.463229 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.650676), count: 4, class_loss = 0.234199, iou_loss = 0.409518, total_loss = 0.643717
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000053, iou_loss = 0.000000, total_loss = 0.000053
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70440, rewritten_bbox = 2.463089 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.822487), count: 4, class_loss = 0.857668, iou_loss = 0.205954, total_loss = 1.063623
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000284, iou_loss = 0.000000, total_loss = 0.000284
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70444, rewritten_bbox = 2.462949 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.758245), count: 4, class_loss = 0.349721, iou_loss = 0.178607, total_loss = 0.528328
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000170, iou_loss = 0.000000, total_loss = 0.000170
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70448, rewritten_bbox = 2.462810 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.530679), count: 3, class_loss = 0.858657, iou_loss = 0.492871, total_loss = 1.351528
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000050, iou_loss = 0.000000, total_loss = 0.000050
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000002, iou_loss = 0.000000, total_loss = 0.000002
#  total_bbox = 70451, rewritten_bbox = 2.462705 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.630083), count: 4, class_loss = 0.723079, iou_loss = 0.273936, total_loss = 0.997015
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000089, iou_loss = 0.000000, total_loss = 0.000089
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70455, rewritten_bbox = 2.462565 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.597104), count: 2, class_loss = 0.590481, iou_loss = 0.176232, total_loss = 0.766713
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.198081), count: 2, class_loss = 0.859716, iou_loss = 2.185112, total_loss = 3.044827
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70459, rewritten_bbox = 2.462425 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.568394), count: 4, class_loss = 1.049227, iou_loss = 0.454845, total_loss = 1.504072
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000036, iou_loss = 0.000000, total_loss = 0.000036
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70463, rewritten_bbox = 2.462285 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.716159), count: 7, class_loss = 1.850920, iou_loss = 0.669365, total_loss = 2.520286
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000038, iou_loss = 0.000000, total_loss = 0.000038
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000002, iou_loss = 0.000000, total_loss = 0.000002
#  total_bbox = 70470, rewritten_bbox = 2.464879 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.627468), count: 4, class_loss = 0.690561, iou_loss = 0.371903, total_loss = 1.062463
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000870, iou_loss = 0.000000, total_loss = 0.000870
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70474, rewritten_bbox = 2.464739 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.643932), count: 3, class_loss = 1.017882, iou_loss = 0.283477, total_loss = 1.301359
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.648234), count: 1, class_loss = 0.285279, iou_loss = 0.092355, total_loss = 0.377634
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000002, iou_loss = 0.000000, total_loss = 0.000002
#  total_bbox = 70478, rewritten_bbox = 2.464599 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.644114), count: 2, class_loss = 1.033266, iou_loss = 0.101235, total_loss = 1.134502
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.513437), count: 1, class_loss = 0.174817, iou_loss = 0.217273, total_loss = 0.392090
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70481, rewritten_bbox = 2.464494 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.625500), count: 3, class_loss = 0.337051, iou_loss = 0.242813, total_loss = 0.579864
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.511997), count: 1, class_loss = 0.344584, iou_loss = 0.233322, total_loss = 0.577906
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70485, rewritten_bbox = 2.464354 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.668202), count: 4, class_loss = 1.080731, iou_loss = 0.403220, total_loss = 1.483950
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.001112, iou_loss = 0.000000, total_loss = 0.001112
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000002, iou_loss = 0.000000, total_loss = 0.000002
#  total_bbox = 70489, rewritten_bbox = 2.464214 %
# 928/1000: loss=0.5 hours left=0.2
#  928: 0.532873, 0.651171 avg loss, 0.000742 rate, 4.313393 seconds, 59392 images, 0.207078 hours left
# Loaded: 0.000122 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.654487), count: 6, class_loss = 1.333968, iou_loss = 0.838318, total_loss = 2.172286
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.759791), count: 2, class_loss = 0.494727, iou_loss = 0.193402, total_loss = 0.688130
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000002, iou_loss = 0.000000, total_loss = 0.000002
#  total_bbox = 70497, rewritten_bbox = 2.468190 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.668286), count: 2, class_loss = 0.240375, iou_loss = 0.230624, total_loss = 0.470999
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.508688), count: 3, class_loss = 0.800533, iou_loss = 0.944522, total_loss = 1.745055
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000002, iou_loss = 0.000000, total_loss = 0.000002
#  total_bbox = 70502, rewritten_bbox = 2.469434 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.523004), count: 6, class_loss = 1.053479, iou_loss = 1.190298, total_loss = 2.243777
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.590670), count: 1, class_loss = 0.463506, iou_loss = 0.184774, total_loss = 0.648280
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70509, rewritten_bbox = 2.469188 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.672483), count: 6, class_loss = 0.813123, iou_loss = 0.628630, total_loss = 1.441754
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.001072, iou_loss = 0.000000, total_loss = 0.001072
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70515, rewritten_bbox = 2.470396 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.643024), count: 14, class_loss = 3.003636, iou_loss = 1.664757, total_loss = 4.668393
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000061, iou_loss = 0.000000, total_loss = 0.000061
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70529, rewritten_bbox = 2.469906 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.579698), count: 4, class_loss = 0.866433, iou_loss = 0.557347, total_loss = 1.423781
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.011469, iou_loss = 0.000000, total_loss = 0.011469
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000002, iou_loss = 0.000000, total_loss = 0.000002
#  total_bbox = 70533, rewritten_bbox = 2.469766 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.626147), count: 4, class_loss = 1.027582, iou_loss = 0.511988, total_loss = 1.539570
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000824, iou_loss = 0.000000, total_loss = 0.000824
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70537, rewritten_bbox = 2.469626 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.672627), count: 4, class_loss = 0.982329, iou_loss = 0.439843, total_loss = 1.422172
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000344, iou_loss = 0.000000, total_loss = 0.000344
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70541, rewritten_bbox = 2.469486 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.676912), count: 3, class_loss = 0.737391, iou_loss = 0.367920, total_loss = 1.105311
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.738455), count: 1, class_loss = 0.377379, iou_loss = 0.073103, total_loss = 0.450482
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70545, rewritten_bbox = 2.469346 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.483771), count: 4, class_loss = 1.150414, iou_loss = 1.062026, total_loss = 2.212440
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.673304), count: 1, class_loss = 0.278712, iou_loss = 0.108816, total_loss = 0.387529
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000002, iou_loss = 0.000000, total_loss = 0.000002
#  total_bbox = 70550, rewritten_bbox = 2.469171 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.542991), count: 5, class_loss = 0.955112, iou_loss = 0.838914, total_loss = 1.794027
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.475184), count: 2, class_loss = 0.645508, iou_loss = 0.540570, total_loss = 1.186079
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000002, iou_loss = 0.000000, total_loss = 0.000002
#  total_bbox = 70557, rewritten_bbox = 2.468926 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.652434), count: 5, class_loss = 1.372705, iou_loss = 0.400838, total_loss = 1.773543
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.390767), count: 2, class_loss = 0.627192, iou_loss = 0.808808, total_loss = 1.436001
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70564, rewritten_bbox = 2.468681 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.698956), count: 4, class_loss = 0.759573, iou_loss = 0.274178, total_loss = 1.033751
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.207900), count: 2, class_loss = 0.626531, iou_loss = 2.670310, total_loss = 3.296840
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000002, iou_loss = 0.000000, total_loss = 0.000002
#  total_bbox = 70570, rewritten_bbox = 2.468471 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.489378), count: 3, class_loss = 0.675418, iou_loss = 0.577069, total_loss = 1.252487
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.769413), count: 1, class_loss = 0.524545, iou_loss = 0.088099, total_loss = 0.612645
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70574, rewritten_bbox = 2.468331 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.603461), count: 6, class_loss = 1.155373, iou_loss = 1.180667, total_loss = 2.336040
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.506572), count: 3, class_loss = 0.951936, iou_loss = 1.067389, total_loss = 2.019325
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70583, rewritten_bbox = 2.468016 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.681043), count: 6, class_loss = 1.352380, iou_loss = 0.673861, total_loss = 2.026241
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.605385), count: 2, class_loss = 0.204955, iou_loss = 0.301320, total_loss = 0.506275
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.494095), count: 1, class_loss = 0.369212, iou_loss = 0.139330, total_loss = 0.508542
#  total_bbox = 70592, rewritten_bbox = 2.471951 %
# 929/1000: loss=0.9 hours left=0.2
#  929: 0.883657, 0.674420 avg loss, 0.000745 rate, 4.410627 seconds, 59456 images, 0.205870 hours left
# Loaded: 0.000097 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.618486), count: 6, class_loss = 0.770757, iou_loss = 0.846737, total_loss = 1.617494
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000137, iou_loss = 0.000000, total_loss = 0.000137
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70598, rewritten_bbox = 2.471741 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.608027), count: 5, class_loss = 1.069409, iou_loss = 0.536951, total_loss = 1.606359
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000038, iou_loss = 0.000000, total_loss = 0.000038
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70603, rewritten_bbox = 2.471566 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.668018), count: 4, class_loss = 1.090974, iou_loss = 0.414588, total_loss = 1.505562
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.340499), count: 1, class_loss = 0.223493, iou_loss = 0.586469, total_loss = 0.809962
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70608, rewritten_bbox = 2.471391 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.728776), count: 3, class_loss = 0.393169, iou_loss = 0.133428, total_loss = 0.526597
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.389351), count: 1, class_loss = 0.426652, iou_loss = 0.627608, total_loss = 1.054259
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70612, rewritten_bbox = 2.471251 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.548497), count: 3, class_loss = 0.240952, iou_loss = 0.583082, total_loss = 0.824034
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.522154), count: 1, class_loss = 0.239602, iou_loss = 0.159350, total_loss = 0.398952
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70616, rewritten_bbox = 2.471111 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.711454), count: 2, class_loss = 0.287943, iou_loss = 0.119730, total_loss = 0.407673
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.432516), count: 2, class_loss = 0.858375, iou_loss = 1.125978, total_loss = 1.984353
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70620, rewritten_bbox = 2.470971 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.673823), count: 5, class_loss = 1.031740, iou_loss = 0.453635, total_loss = 1.485375
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000029, iou_loss = 0.000000, total_loss = 0.000029
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70625, rewritten_bbox = 2.470796 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.587045), count: 4, class_loss = 0.704693, iou_loss = 0.457719, total_loss = 1.162412
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000288, iou_loss = 0.000000, total_loss = 0.000288
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000002, iou_loss = 0.000000, total_loss = 0.000002
#  total_bbox = 70629, rewritten_bbox = 2.470657 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.591638), count: 6, class_loss = 1.295305, iou_loss = 0.720622, total_loss = 2.015926
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000011, iou_loss = 0.000000, total_loss = 0.000011
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70635, rewritten_bbox = 2.470447 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.625815), count: 3, class_loss = 0.494977, iou_loss = 0.373374, total_loss = 0.868351
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.502214), count: 10, class_loss = 2.911211, iou_loss = 3.416069, total_loss = 6.327280
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.461677), count: 1, class_loss = 0.532404, iou_loss = 0.337189, total_loss = 0.869593
#  total_bbox = 70649, rewritten_bbox = 2.469957 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.691198), count: 6, class_loss = 1.168011, iou_loss = 0.535947, total_loss = 1.703958
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000045, iou_loss = 0.000000, total_loss = 0.000045
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70655, rewritten_bbox = 2.469747 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.739185), count: 3, class_loss = 0.603911, iou_loss = 0.358579, total_loss = 0.962490
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.585196), count: 2, class_loss = 0.469246, iou_loss = 0.459124, total_loss = 0.928370
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.307518), count: 1, class_loss = 0.482906, iou_loss = 0.825189, total_loss = 1.308095
#  total_bbox = 70661, rewritten_bbox = 2.469538 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.697466), count: 3, class_loss = 0.869639, iou_loss = 0.340413, total_loss = 1.210052
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.279285), count: 1, class_loss = 0.239106, iou_loss = 0.756099, total_loss = 0.995204
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000002, iou_loss = 0.000000, total_loss = 0.000002
#  total_bbox = 70665, rewritten_bbox = 2.469398 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.706020), count: 5, class_loss = 0.909372, iou_loss = 0.327332, total_loss = 1.236704
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.460766), count: 1, class_loss = 0.266938, iou_loss = 0.192786, total_loss = 0.459724
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000002, iou_loss = 0.000000, total_loss = 0.000002
#  total_bbox = 70671, rewritten_bbox = 2.469188 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.656419), count: 3, class_loss = 0.434584, iou_loss = 0.208085, total_loss = 0.642669
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.493992), count: 1, class_loss = 0.303901, iou_loss = 0.197802, total_loss = 0.501703
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70675, rewritten_bbox = 2.469049 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.591531), count: 8, class_loss = 2.202090, iou_loss = 1.235263, total_loss = 3.437352
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.602606), count: 2, class_loss = 0.632531, iou_loss = 0.286535, total_loss = 0.919066
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70685, rewritten_bbox = 2.468699 %
# 930/1000: loss=0.8 hours left=0.2
#  930: 0.786878, 0.685666 avg loss, 0.000748 rate, 4.325428 seconds, 59520 images, 0.204681 hours left
# Loaded: 0.000109 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.614412), count: 5, class_loss = 1.128473, iou_loss = 0.653412, total_loss = 1.781885
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.001816, iou_loss = 0.000000, total_loss = 0.001816
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70690, rewritten_bbox = 2.468524 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.592267), count: 6, class_loss = 1.083322, iou_loss = 0.795278, total_loss = 1.878600
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.530391), count: 5, class_loss = 1.664827, iou_loss = 1.437673, total_loss = 3.102500
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000002, iou_loss = 0.000000, total_loss = 0.000002
#  total_bbox = 70701, rewritten_bbox = 2.469555 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.593255), count: 4, class_loss = 0.970134, iou_loss = 0.474575, total_loss = 1.444710
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000125, iou_loss = 0.000000, total_loss = 0.000125
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70705, rewritten_bbox = 2.469415 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.624531), count: 5, class_loss = 1.203852, iou_loss = 0.393775, total_loss = 1.597627
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000208, iou_loss = 0.000000, total_loss = 0.000208
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70710, rewritten_bbox = 2.469241 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.652808), count: 4, class_loss = 0.600681, iou_loss = 0.483598, total_loss = 1.084278
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000073, iou_loss = 0.000000, total_loss = 0.000073
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70714, rewritten_bbox = 2.469101 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.651487), count: 5, class_loss = 0.776148, iou_loss = 0.523237, total_loss = 1.299385
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000028, iou_loss = 0.000000, total_loss = 0.000028
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70719, rewritten_bbox = 2.468926 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.616606), count: 4, class_loss = 0.990593, iou_loss = 0.568354, total_loss = 1.558947
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.290724), count: 1, class_loss = 0.265874, iou_loss = 0.708098, total_loss = 0.973972
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70724, rewritten_bbox = 2.468752 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.744785), count: 3, class_loss = 0.294015, iou_loss = 0.195848, total_loss = 0.489863
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.434690), count: 1, class_loss = 0.428682, iou_loss = 0.336593, total_loss = 0.765275
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70728, rewritten_bbox = 2.468612 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.600916), count: 4, class_loss = 0.576516, iou_loss = 0.465518, total_loss = 1.042034
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000034, iou_loss = 0.000000, total_loss = 0.000034
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70732, rewritten_bbox = 2.468472 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.586681), count: 5, class_loss = 1.219407, iou_loss = 0.733798, total_loss = 1.953205
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000562, iou_loss = 0.000000, total_loss = 0.000562
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70737, rewritten_bbox = 2.468298 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.690086), count: 7, class_loss = 1.089722, iou_loss = 0.760572, total_loss = 1.850294
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000111, iou_loss = 0.000000, total_loss = 0.000111
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 70744, rewritten_bbox = 2.469467 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.665289), count: 4, class_loss = 0.760979, iou_loss = 0.459713, total_loss = 1.220692
# ...
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.768019), count: 3, class_loss = 0.590481, iou_loss = 0.207690, total_loss = 0.798171
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.684343), count: 1, class_loss = 0.253049, iou_loss = 0.092577, total_loss = 0.345626
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000476, iou_loss = 0.000000, total_loss = 0.000476
#  total_bbox = 76465, rewritten_bbox = 2.449487 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.574453), count: 3, class_loss = 0.765420, iou_loss = 0.295138, total_loss = 1.060557
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000116, iou_loss = 0.000000, total_loss = 0.000116
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000003, iou_loss = 0.000000, total_loss = 0.000003
#  total_bbox = 76468, rewritten_bbox = 2.449391 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.644721), count: 6, class_loss = 0.792251, iou_loss = 0.799666, total_loss = 1.591917
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.008928, iou_loss = 0.000000, total_loss = 0.008928
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000038, iou_loss = 0.000000, total_loss = 0.000038
#  total_bbox = 76474, rewritten_bbox = 2.449198 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.664572), count: 5, class_loss = 0.175636, iou_loss = 0.357495, total_loss = 0.533131
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000121, iou_loss = 0.000000, total_loss = 0.000121
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000005, iou_loss = 0.000000, total_loss = 0.000005
#  total_bbox = 76479, rewritten_bbox = 2.449038 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.710445), count: 7, class_loss = 1.355883, iou_loss = 0.824509, total_loss = 2.180392
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000049, iou_loss = 0.000000, total_loss = 0.000049
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000003, iou_loss = 0.000000, total_loss = 0.000003
#  total_bbox = 76486, rewritten_bbox = 2.448814 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.789235), count: 4, class_loss = 0.601220, iou_loss = 0.213103, total_loss = 0.814324
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.013516, iou_loss = 0.000000, total_loss = 0.013516
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000005, iou_loss = 0.000000, total_loss = 0.000005
#  total_bbox = 76490, rewritten_bbox = 2.448686 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.718889), count: 4, class_loss = 0.496687, iou_loss = 0.248605, total_loss = 0.745292
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000224, iou_loss = 0.000000, total_loss = 0.000224
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000007, iou_loss = 0.000000, total_loss = 0.000007
#  total_bbox = 76494, rewritten_bbox = 2.448558 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.747351), count: 4, class_loss = 1.029665, iou_loss = 0.353237, total_loss = 1.382902
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000349, iou_loss = 0.000000, total_loss = 0.000349
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000007, iou_loss = 0.000000, total_loss = 0.000007
#  total_bbox = 76498, rewritten_bbox = 2.448430 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.678433), count: 5, class_loss = 1.151242, iou_loss = 0.295427, total_loss = 1.446669
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000013, iou_loss = 0.000000, total_loss = 0.000013
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000003, iou_loss = 0.000000, total_loss = 0.000003
#  total_bbox = 76503, rewritten_bbox = 2.448270 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.618555), count: 8, class_loss = 1.472375, iou_loss = 0.887433, total_loss = 2.359808
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.529694), count: 1, class_loss = 0.352634, iou_loss = 0.260655, total_loss = 0.613289
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000012, iou_loss = 0.000000, total_loss = 0.000012
#  total_bbox = 76512, rewritten_bbox = 2.447982 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.634037), count: 3, class_loss = 0.605162, iou_loss = 0.249305, total_loss = 0.854467
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.387356), count: 1, class_loss = 0.268392, iou_loss = 0.461764, total_loss = 0.730156
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000054, iou_loss = 0.000000, total_loss = 0.000054
#  total_bbox = 76516, rewritten_bbox = 2.447854 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.684952), count: 4, class_loss = 0.450336, iou_loss = 0.274340, total_loss = 0.724675
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000216, iou_loss = 0.000000, total_loss = 0.000216
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000004, iou_loss = 0.000000, total_loss = 0.000004
#  total_bbox = 76520, rewritten_bbox = 2.447726 %
# 999/1000: loss=0.5 hours left=0.1
#  999: 0.487303, 0.591585 avg loss, 0.000996 rate, 4.304457 seconds, 63936 images, 0.121585 hours left
# Loaded: 0.000114 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.677908), count: 4, class_loss = 1.409732, iou_loss = 0.370083, total_loss = 1.779815
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000590, iou_loss = 0.000000, total_loss = 0.000590
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000004, iou_loss = 0.000000, total_loss = 0.000004
#  total_bbox = 76524, rewritten_bbox = 2.447598 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.742184), count: 6, class_loss = 0.841733, iou_loss = 0.457799, total_loss = 1.299532
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000950, iou_loss = 0.000000, total_loss = 0.000950
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000004, iou_loss = 0.000000, total_loss = 0.000004
#  total_bbox = 76530, rewritten_bbox = 2.447406 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.741046), count: 4, class_loss = 0.581835, iou_loss = 0.240575, total_loss = 0.822410
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000183, iou_loss = 0.000000, total_loss = 0.000183
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000003, iou_loss = 0.000000, total_loss = 0.000003
#  total_bbox = 76534, rewritten_bbox = 2.447278 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.700220), count: 3, class_loss = 0.207294, iou_loss = 0.211157, total_loss = 0.418451
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.002127, iou_loss = 0.000000, total_loss = 0.002127
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.615612), count: 1, class_loss = 0.474676, iou_loss = 0.163519, total_loss = 0.638196
#  total_bbox = 76538, rewritten_bbox = 2.447150 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.648185), count: 4, class_loss = 0.779671, iou_loss = 0.441731, total_loss = 1.221402
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000064, iou_loss = 0.000000, total_loss = 0.000064
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000005, iou_loss = 0.000000, total_loss = 0.000005
#  total_bbox = 76542, rewritten_bbox = 2.447022 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.689963), count: 7, class_loss = 0.802604, iou_loss = 1.262363, total_loss = 2.064968
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.002101, iou_loss = 0.000000, total_loss = 0.002101
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.246734), count: 1, class_loss = 0.392894, iou_loss = 0.850873, total_loss = 1.243767
#  total_bbox = 76550, rewritten_bbox = 2.449379 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.698818), count: 5, class_loss = 0.480933, iou_loss = 0.467559, total_loss = 0.948492
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.645718), count: 1, class_loss = 0.254847, iou_loss = 0.171602, total_loss = 0.426449
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000011, iou_loss = 0.000000, total_loss = 0.000011
#  total_bbox = 76556, rewritten_bbox = 2.449188 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.580734), count: 3, class_loss = 0.268460, iou_loss = 0.271665, total_loss = 0.540126
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.461102), count: 2, class_loss = 0.529363, iou_loss = 0.614618, total_loss = 1.143982
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.478849), count: 1, class_loss = 0.375467, iou_loss = 0.212766, total_loss = 0.588233
#  total_bbox = 76562, rewritten_bbox = 2.448996 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.630780), count: 4, class_loss = 0.685662, iou_loss = 0.495171, total_loss = 1.180833
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.250465), count: 1, class_loss = 0.287635, iou_loss = 0.906398, total_loss = 1.194032
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000007, iou_loss = 0.000000, total_loss = 0.000007
#  total_bbox = 76567, rewritten_bbox = 2.448836 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.696577), count: 4, class_loss = 0.732815, iou_loss = 0.338461, total_loss = 1.071276
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.001032, iou_loss = 0.000000, total_loss = 0.001032
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000004, iou_loss = 0.000000, total_loss = 0.000004
#  total_bbox = 76571, rewritten_bbox = 2.448708 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.784299), count: 2, class_loss = 0.558015, iou_loss = 0.107004, total_loss = 0.665019
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.478781), count: 8, class_loss = 2.070771, iou_loss = 2.846419, total_loss = 4.917190
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000027, iou_loss = 0.000000, total_loss = 0.000027
#  total_bbox = 76581, rewritten_bbox = 2.448388 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.707399), count: 4, class_loss = 0.706079, iou_loss = 0.399346, total_loss = 1.105426
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000122, iou_loss = 0.000000, total_loss = 0.000122
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000003, iou_loss = 0.000000, total_loss = 0.000003
#  total_bbox = 76585, rewritten_bbox = 2.448260 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.580649), count: 3, class_loss = 1.040394, iou_loss = 0.385422, total_loss = 1.425816
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.636049), count: 1, class_loss = 0.078106, iou_loss = 0.139934, total_loss = 0.218041
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000057, iou_loss = 0.000000, total_loss = 0.000057
#  total_bbox = 76589, rewritten_bbox = 2.448132 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.725028), count: 4, class_loss = 0.419212, iou_loss = 0.292446, total_loss = 0.711658
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.002120, iou_loss = 0.000000, total_loss = 0.002120
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000004, iou_loss = 0.000000, total_loss = 0.000004
#  total_bbox = 76593, rewritten_bbox = 2.448004 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.706248), count: 4, class_loss = 1.020173, iou_loss = 0.352116, total_loss = 1.372289
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000026, iou_loss = 0.000000, total_loss = 0.000026
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000003, iou_loss = 0.000000, total_loss = 0.000003
#  total_bbox = 76597, rewritten_bbox = 2.447876 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.594577), count: 4, class_loss = 0.640250, iou_loss = 0.343701, total_loss = 0.983951
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.022752, iou_loss = 0.000000, total_loss = 0.022752
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000002, iou_loss = 0.000000, total_loss = 0.000002
#  total_bbox = 76601, rewritten_bbox = 2.447749 %
# 1000/1000: loss=0.6 hours left=0.1
#  1000: 0.583616, 0.590788 avg loss, 0.001000 rate, 4.221118 seconds, 64000 images, 0.120381 hours left
# Saving weights to /mydrive/yolov3/backup//yolov3_custom_1000.weights
# Saving weights to /mydrive/yolov3/backup//yolov3_custom_last.weights

# %% [markdown]
# # Step 6: Run Your Custom Object Detector!!!
# You have done it! You now have a custom object detector to make your very own detections. Time to test it out and have some fun!

# %%
# need to set our custom cfg to test mode
# %cd cfg
# !sed -i 's/batch=64/batch=1/' yolov3_custom.cfg
# !sed -i 's/subdivisions=16/subdivisions=1/' yolov3_custom.cfg
# %cd ..
# Out:
# /darknet/cfg
# /darknet

# %%
# run your custom detector with this command (upload an image to your google drive to test, thresh flag sets accuracy that detection must be in order to show it)
# %cd content/darknet/
# !ls /mydrive
# !ls darknet/data
# !./darknet detector test data/obj.data cfg/yolov3_custom.cfg /mydrive/yolov3/backup/yolov3_custom_last.weights /mydrive/yolov3/image_test/Test_handgun.jpg -thresh 0.3 --out 'predictions.jpg'
#imShow('/mydrive/yolov3/image_test/Test1.jpg')
imShow('predictions.jpg')
# Out:
# [Errno 2] No such file or directory: 'content/darknet/'
# /darknet
#  1H.pdf				      Magasin.html
#  ClaritaHAWAT_LU_WebDev		     'My Drive'
#  Classroom			      Produit.html
# 'Colab Notebooks'		      project_01.zip
#  Definition.html		     'Reborn and.txt'
#  DOC-20190225-WA0057.xlsx	     'Table (1).html'
#  efficientnet			      Table.html
# 'How to get started with Drive.pdf'  'Untitled presentation (1).gslides'
# 'Lesson 1 - FlowChart.rar'	     'Untitled presentation (2).gslides'
#  Library.html			     'Untitled presentation.gslides'
#  Links.html			      yolov3
#  List.html			     'yolov3 2'
# ls: cannot access 'darknet/data': Not a directory
#  GPU isn't used
#  OpenCV version: 4.5.4
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5,  wt = 0, wn = 0, outputs: 104 x 104 x 128 0.001 BF
#    9 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#   10 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#   11 Shortcut Layer: 8,  wt = 0, wn = 0, outputs: 104 x 104 x 128 0.001 BF
#   12 conv    256       3 x 3/ 2    104 x 104 x 128 ->   52 x  52 x 256 1.595 BF
#   13 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   14 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   15 Shortcut Layer: 12,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   16 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   17 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   18 Shortcut Layer: 15,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   19 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   20 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   21 Shortcut Layer: 18,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   22 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   23 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   24 Shortcut Layer: 21,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   25 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   26 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   27 Shortcut Layer: 24,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   28 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   29 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   30 Shortcut Layer: 27,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   31 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   32 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   33 Shortcut Layer: 30,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   34 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   35 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   36 Shortcut Layer: 33,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   37 conv    512       3 x 3/ 2     52 x  52 x 256 ->   26 x  26 x 512 1.595 BF
#   38 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   39 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   40 Shortcut Layer: 37,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   41 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   42 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   43 Shortcut Layer: 40,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   44 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   45 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   46 Shortcut Layer: 43,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   47 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   48 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   49 Shortcut Layer: 46,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   50 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   51 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   52 Shortcut Layer: 49,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   53 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   54 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   55 Shortcut Layer: 52,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   56 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   57 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   58 Shortcut Layer: 55,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   59 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   60 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   61 Shortcut Layer: 58,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   62 conv   1024       3 x 3/ 2     26 x  26 x 512 ->   13 x  13 x1024 1.595 BF
#   63 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   64 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   65 Shortcut Layer: 62,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   66 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   67 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   68 Shortcut Layer: 65,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   69 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   70 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   71 Shortcut Layer: 68,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   72 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   73 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   74 Shortcut Layer: 71,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   75 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   76 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   77 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   78 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   79 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   80 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   81 conv     24       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x  24 0.008 BF
#   82 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
#   83 route  79 		                           ->   13 x  13 x 512
#   84 conv    256       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 256 0.044 BF
#   85 upsample                 2x    13 x  13 x 256 ->   26 x  26 x 256
#   86 route  85 61 	                           ->   26 x  26 x 768
#   87 conv    256       1 x 1/ 1     26 x  26 x 768 ->   26 x  26 x 256 0.266 BF
#   88 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   89 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   90 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   91 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   92 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   93 conv     24       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x  24 0.017 BF
#   94 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
#   95 route  91 		                           ->   26 x  26 x 256
#   96 conv    128       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 128 0.044 BF
#   97 upsample                 2x    26 x  26 x 128 ->   52 x  52 x 128
#   98 route  97 36 	                           ->   52 x  52 x 384
#   99 conv    128       1 x 1/ 1     52 x  52 x 384 ->   52 x  52 x 128 0.266 BF
#  100 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#  101 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#  102 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#  103 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#  104 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#  105 conv     24       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x  24 0.033 BF
#  106 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
# Total BFLOPS 65.319
# avg_outputs = 517121
# Loading weights from /mydrive/yolov3/backup/yolov3_custom_last.weights...
#  seen 64, trained: 64 K-images (1 Kilo-batches_64)
# Done! Loaded 107 layers from weights-file
#  Detection layer: 82 - type = 28
#  Detection layer: 94 - type = 28
#  Detection layer: 106 - type = 28
# /mydrive/yolov3/image_test/Test_handgun.jpg: Predicted in 9807.642000 milli-seconds.
# Handgun: 55%
# OpenCV exception: show_image_cv

# %%
# !pip install darknet
# Out:
# Requirement already satisfied: darknet in /usr/local/lib/python3.10/dist-packages (0.3)

# %%
yolov3_model = load_model("cfg/yolov3_custom.cfg")

new_weights_path = "/mydrive/yolov3/backup/yolov3_custom_last.weights"
yolov3_model.load_weights(new_weights_path)

#model = load_yolov3_model("/mydrive/yolov3/backup/yolov3_custom_last.weights", "cfg/yolov3_custom.cfg")
yolov3_model.save("yolov3_custom_model.h5")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-69-aa2bf9d69d95> in <cell line: 1>()
# ----> 1 yolov3_model = load_model("cfg/yolov3_custom.cfg")
#       2
#       3 new_weights_path = "/mydrive/yolov3/backup/yolov3_custom_last.weights"
#       4 yolov3_model.load_weights(new_weights_path)
#       5
#
# NameError: name 'load_model' is not defined

# %% [markdown]
# # Thanks!
# Thanks for following along this tutorial, I hope it worked well for all of you!
#
# If you enjoy YOLOv3 check out my other videos and subscribe to my channel so you don't miss out on any other amazing YOLOv3 content!
#
# [The AI Guy](https://www.youtube.com/channel/UCrydcKaojc44XnuXrfhlV8Q)
